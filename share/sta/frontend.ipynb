# %%
import os, sys, json
sys.path.append(os.path.realpath(f"{os.getcwd()}/../../"))

from autocog.pm.sta.frontend import frontend
from autocog.utility.pynb import wrap_graphviz, display

# `wrap_frontend` displays the parse tree then call the normal frontend to produce the AST
from autocog.pm.sta.devel import wrap_frontend
# Out:
# Warning: Package `llama_cpp` needed for LLaMa wrapper (pip install git+https://github.com/tristanvdb/llama-cpp-python@choice-dev)
# Warning: Package `transformers` needed for (Huggingface's) transformers wrapper

# %%
tree = frontend("""
format bool {
    is enum("true","false");
    annotate "a bolean value is either true or false";
}

format sentence {
    argument length=50;
    argument language="english";
    is text<length=$length>;
    annotate f"a grammatically correct {language} sentence";
}

struct a_choice {
    is {
        value   is sentence<40>;
        correct is bool;
    }
    annotate {
        .value   as "the value of the choice";
        .correct as "you decide whether this choice is correct or not";
    }
}

prompt mmlu_main {
    is {
        topic      is text<20>;
        question   is sentence;
        choices[4] is a_choice;
        answer     is repeat(.choices.value);
    }
    channel {
        to .topic         from ?topic;
        to .question      from ?question;
        to .choices.value from ?choices;
    }
    return .answer;
    annotate {
        .topic    as "the general category from which the question was taken";
        .question as "the question that you have to answer";
        .choices  as "you judge whether each choice is correct or not";
        .answer   as "you repeat the value of the choice that best answer the question";
    }
}
""")
dotstr = tree.toGraphViz()
# print(dotstr)
wrap_graphviz(dotstr)
# Out:
#         <div class="svg_container_2b65a153_be20_4702_91d4_13ad3a92a7f0">
#             <style>
#                 .svg_container_2b65a153_be20_4702_91d4_13ad3a92a7f0 {
#                     overflow:hidden
#                 }
#                 .svg_container_2b65a153_be20_4702_91d4_13ad3a92a7f0 SVG {
#                     height:800px
#                 }
#             </style>
#             <script src="https://bumbu.me/svg-pan-zoom/dist/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_2b65a153_be20_4702_91d4_13ad3a92a7f0 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.01, maxZoom: 1000.});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="6481pt" height="610pt"
#  viewBox="0.00 0.00 6481.00 610.13" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 606.13)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-606.13 6477,-606.13 6477,4 -4,4"/>
# <!-- n_0 -->
# <g id="node1" class="node">
# <title>n_0</title>
# <ellipse fill="none" stroke="black" cx="1075" cy="-584.13" rx="51.19" ry="18"/>
# <text text-anchor="middle" x="1075" y="-580.43" font-family="Times,serif" font-size="14.00">Program</text>
# </g>
# <!-- n_1 -->
# <g id="node2" class="node">
# <title>n_1</title>
# <ellipse fill="none" stroke="black" cx="360" cy="-488.26" rx="48.17" ry="26.74"/>
# <text text-anchor="middle" x="360" y="-492.06" font-family="Times,serif" font-size="14.00">Format</text>
# <text text-anchor="middle" x="360" y="-477.06" font-family="Times,serif" font-size="14.00">bool</text>
# </g>
# <!-- n_0&#45;&gt;n_1 -->
# <g id="edge5" class="edge">
# <title>n_0&#45;&gt;n_1</title>
# <path fill="none" stroke="black" d="M1027.81,-576.93C901.14,-560.3 554.02,-514.73 416.85,-496.72"/>
# <polygon fill="black" stroke="black" points="416.94,-493.2 406.57,-495.37 416.03,-500.14 416.94,-493.2"/>
# <text text-anchor="middle" x="837" y="-536.93" font-family="Times,serif" font-size="14.00">format[0]</text>
# </g>
# <!-- n_6 -->
# <g id="node7" class="node">
# <title>n_6</title>
# <ellipse fill="none" stroke="black" cx="877" cy="-488.26" rx="56.64" ry="26.74"/>
# <text text-anchor="middle" x="877" y="-492.06" font-family="Times,serif" font-size="14.00">Format</text>
# <text text-anchor="middle" x="877" y="-477.06" font-family="Times,serif" font-size="14.00">sentence</text>
# </g>
# <!-- n_0&#45;&gt;n_6 -->
# <g id="edge14" class="edge">
# <title>n_0&#45;&gt;n_6</title>
# <path fill="none" stroke="black" d="M1045.78,-569.28C1014.15,-554.28 963.17,-530.11 925.51,-512.25"/>
# <polygon fill="black" stroke="black" points="926.77,-508.98 916.24,-507.86 923.77,-515.31 926.77,-508.98"/>
# <text text-anchor="middle" x="1034" y="-536.93" font-family="Times,serif" font-size="14.00">format[1]</text>
# </g>
# <!-- n_15 -->
# <g id="node16" class="node">
# <title>n_15</title>
# <ellipse fill="none" stroke="black" cx="1580" cy="-488.26" rx="54.39" ry="26.74"/>
# <text text-anchor="middle" x="1580" y="-492.06" font-family="Times,serif" font-size="14.00">Struct</text>
# <text text-anchor="middle" x="1580" y="-477.06" font-family="Times,serif" font-size="14.00">a_choice</text>
# </g>
# <!-- n_0&#45;&gt;n_15 -->
# <g id="edge29" class="edge">
# <title>n_0&#45;&gt;n_15</title>
# <path fill="none" stroke="black" d="M1119.37,-574.88C1210.09,-558.01 1416.9,-519.57 1519.69,-500.47"/>
# <polygon fill="black" stroke="black" points="1520.42,-503.89 1529.61,-498.62 1519.14,-497.01 1520.42,-503.89"/>
# <text text-anchor="middle" x="1374.5" y="-536.93" font-family="Times,serif" font-size="14.00">struct[0]</text>
# </g>
# <!-- n_30 -->
# <g id="node31" class="node">
# <title>n_30</title>
# <ellipse fill="none" stroke="black" cx="3929" cy="-488.26" rx="70.01" ry="26.74"/>
# <text text-anchor="middle" x="3929" y="-492.06" font-family="Times,serif" font-size="14.00">Prompt</text>
# <text text-anchor="middle" x="3929" y="-477.06" font-family="Times,serif" font-size="14.00">mmlu_main</text>
# </g>
# <!-- n_0&#45;&gt;n_30 -->
# <g id="edge81" class="edge">
# <title>n_0&#45;&gt;n_30</title>
# <path fill="none" stroke="black" d="M1126.05,-581.45C1468.27,-570.19 3427.86,-505.74 3849.2,-491.88"/>
# <polygon fill="black" stroke="black" points="3849.58,-495.37 3859.46,-491.54 3849.35,-488.37 3849.58,-495.37"/>
# <text text-anchor="middle" x="2624.5" y="-536.93" font-family="Times,serif" font-size="14.00">prompt[0]</text>
# </g>
# <!-- n_2 -->
# <g id="node3" class="node">
# <title>n_2</title>
# <ellipse fill="none" stroke="black" cx="88" cy="-383.52" rx="65.52" ry="26.74"/>
# <text text-anchor="middle" x="88" y="-387.32" font-family="Times,serif" font-size="14.00">EnumType</text>
# <text text-anchor="middle" x="88" y="-372.32" font-family="Times,serif" font-size="14.00">enum</text>
# </g>
# <!-- n_1&#45;&gt;n_2 -->
# <g id="edge3" class="edge">
# <title>n_1&#45;&gt;n_2</title>
# <path fill="none" stroke="black" d="M320.74,-472.43C274.62,-455.01 197.72,-425.96 145.03,-406.06"/>
# <polygon fill="black" stroke="black" points="146.07,-402.71 135.48,-402.45 143.6,-409.26 146.07,-402.71"/>
# <text text-anchor="middle" x="257" y="-432.19" font-family="Times,serif" font-size="14.00">type</text>
# </g>
# <!-- n_5 -->
# <g id="node6" class="node">
# <title>n_5</title>
# <ellipse fill="none" stroke="black" cx="360" cy="-383.52" rx="187.67" ry="18"/>
# <text text-anchor="middle" x="360" y="-379.82" font-family="Times,serif" font-size="14.00">&quot;a bolean value is either true or false&quot;</text>
# </g>
# <!-- n_1&#45;&gt;n_5 -->
# <g id="edge4" class="edge">
# <title>n_1&#45;&gt;n_5</title>
# <path fill="none" stroke="black" d="M360,-461.33C360,-446.31 360,-427.41 360,-412.11"/>
# <polygon fill="black" stroke="black" points="363.5,-411.72 360,-401.72 356.5,-411.72 363.5,-411.72"/>
# <text text-anchor="middle" x="398.5" y="-432.19" font-family="Times,serif" font-size="14.00">annotation</text>
# </g>
# <!-- n_3 -->
# <g id="node4" class="node">
# <title>n_3</title>
# <ellipse fill="none" stroke="black" cx="39" cy="-268.17" rx="38.99" ry="18"/>
# <text text-anchor="middle" x="39" y="-264.47" font-family="Times,serif" font-size="14.00">&quot;true&quot;</text>
# </g>
# <!-- n_2&#45;&gt;n_3 -->
# <g id="edge1" class="edge">
# <title>n_2&#45;&gt;n_3</title>
# <path fill="none" stroke="black" d="M68.73,-357.39C64.78,-351.46 60.94,-345.01 58,-338.65 51.78,-325.21 47.25,-309.35 44.18,-296.18"/>
# <polygon fill="black" stroke="black" points="47.57,-295.31 42.02,-286.28 40.73,-296.8 47.57,-295.31"/>
# <text text-anchor="middle" x="87" y="-327.45" font-family="Times,serif" font-size="14.00">value[0]</text>
# </g>
# <!-- n_4 -->
# <g id="node5" class="node">
# <title>n_4</title>
# <ellipse fill="none" stroke="black" cx="138" cy="-268.17" rx="41.69" ry="18"/>
# <text text-anchor="middle" x="138" y="-264.47" font-family="Times,serif" font-size="14.00">&quot;false&quot;</text>
# </g>
# <!-- n_2&#45;&gt;n_4 -->
# <g id="edge2" class="edge">
# <title>n_2&#45;&gt;n_4</title>
# <path fill="none" stroke="black" d="M105.74,-357.18C109.44,-351.26 113.09,-344.87 116,-338.65 122.34,-325.08 127.52,-309.21 131.26,-296.06"/>
# <polygon fill="black" stroke="black" points="134.69,-296.77 133.94,-286.2 127.94,-294.93 134.69,-296.77"/>
# <text text-anchor="middle" x="152" y="-327.45" font-fa
