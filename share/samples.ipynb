# %%
import os, sys, json
sys.path.append("/home/tristan/projects/LLM/AutoCog")
from autocog.language.sta.frontend import frontend
from autocog.utility.pynb import wrap_graphviz, display
# Out:
# Warning: Package `llama_cpp` needed for LLaMa wrapper (pip install git+https://github.com/tristanvdb/llama-cpp-python@choice-dev)
# Warning: Package `transformers` needed for (Huggingface's) transformers wrapper

# %% [markdown]
# ## Single prompt and _compact_
#
# **Note**:
#  - `text` is implicitly `text<INF>` (meaning no limit on number of tokens)
#    - **but** can only be used if target of a channel

# %%
tree = frontend("""
define default_number_of_choices=4;
argument N=$default_number_of_choices;
prompt mmlu_main {
    is {
        topic is text;
        question is text;
        choices[$N] is {
            value is text;
            correct is bool;
        }
        answer is repeat(.choices.value);
    }
    channel {
        to .topic         from ?topic;
        to .question      from ?question;
        to .choices.value from ?choices;
    }
    return {
        from .answer;
    }
    annotate {
        .topic           as "the general category from which the question was taken";
        .question        as "the question that you have to answer";
        .choices         as "you judge whether each choice is correct or not";
        .choices.value   as "the value of the choice";
        .choices.correct as "you decide whether this choice is correct or not";
        .answer          as "you repeat the value of the choice that best answer the question";
    }
}
""")
wrap_graphviz(tree.toGraphViz())
# Out:
#         <div class="svg_container_b13a1e90_9430_4266_a56c_19f9074e751f">
#             <style>
#                 .svg_container_b13a1e90_9430_4266_a56c_19f9074e751f {
#                     overflow:hidden
#                 }
#                 .svg_container_b13a1e90_9430_4266_a56c_19f9074e751f SVG {
#                     height:800px
#                 }
#             </style>
#             <script src="https://bumbu.me/svg-pan-zoom/dist/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_b13a1e90_9430_4266_a56c_19f9074e751f svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.01, maxZoom: 1000.});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="4818pt" height="610pt"
#  viewBox="0.00 0.00 4818.03 610.13" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 606.13)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-606.13 4814.03,-606.13 4814.03,4 -4,4"/>
# <!-- n_0 -->
# <g id="node1" class="node">
# <title>n_0</title>
# <ellipse fill="none" stroke="black" cx="445.03" cy="-584.13" rx="51.19" ry="18"/>
# <text text-anchor="middle" x="445.03" y="-580.43" font-family="Times,serif" font-size="14.00">Program</text>
# </g>
# <!-- n_1 -->
# <g id="node2" class="node">
# <title>n_1</title>
# <ellipse fill="none" stroke="black" cx="226.03" cy="-488.26" rx="147.57" ry="26.74"/>
# <text text-anchor="middle" x="226.03" y="-492.06" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="226.03" y="-477.06" font-family="Times,serif" font-size="14.00">default_number_of_choices</text>
# </g>
# <!-- n_0&#45;&gt;n_1 -->
# <g id="edge2" class="edge">
# <title>n_0&#45;&gt;n_1</title>
# <path fill="none" stroke="black" d="M413.48,-569.68C398.24,-563.18 379.68,-555.26 363.03,-548.13 339.5,-538.05 313.71,-526.97 290.92,-517.18"/>
# <polygon fill="black" stroke="black" points="292.25,-513.94 281.68,-513.2 289.48,-520.37 292.25,-513.94"/>
# <text text-anchor="middle" x="402.03" y="-536.93" font-family="Times,serif" font-size="14.00">variable[0]</text>
# </g>
# <!-- n_3 -->
# <g id="node4" class="node">
# <title>n_3</title>
# <ellipse fill="none" stroke="black" cx="445.03" cy="-488.26" rx="53.07" ry="26.74"/>
# <text text-anchor="middle" x="445.03" y="-492.06" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="445.03" y="-477.06" font-family="Times,serif" font-size="14.00">N</text>
# </g>
# <!-- n_0&#45;&gt;n_3 -->
# <g id="edge4" class="edge">
# <title>n_0&#45;&gt;n_3</title>
# <path fill="none" stroke="black" d="M445.03,-565.91C445.03,-554.61 445.03,-539.4 445.03,-525.5"/>
# <polygon fill="black" stroke="black" points="448.53,-525.23 445.03,-515.23 441.53,-525.23 448.53,-525.23"/>
# <text text-anchor="middle" x="484.03" y="-536.93" font-family="Times,serif" font-size="14.00">variable[1]</text>
# </g>
# <!-- n_5 -->
# <g id="node6" class="node">
# <title>n_5</title>
# <ellipse fill="none" stroke="black" cx="1906.03" cy="-488.26" rx="70.01" ry="26.74"/>
# <text text-anchor="middle" x="1906.03" y="-492.06" font-family="Times,serif" font-size="14.00">Prompt</text>
# <text text-anchor="middle" x="1906.03" y="-477.06" font-family="Times,serif" font-size="14.00">mmlu_main</text>
# </g>
# <!-- n_0&#45;&gt;n_5 -->
# <g id="edge66" class="edge">
# <title>n_0&#45;&gt;n_5</title>
# <path fill="none" stroke="black" d="M495.32,-579.9C711.46,-566.01 1562.4,-511.34 1827.05,-494.33"/>
# <polygon fill="black" stroke="black" points="1827.59,-497.8 1837.34,-493.67 1827.14,-490.82 1827.59,-497.8"/>
# <text text-anchor="middle" x="1256.53" y="-536.93" font-family="Times,serif" font-size="14.00">prompt[0]</text>
# </g>
# <!-- n_2 -->
# <g id="node3" class="node">
# <title>n_2</title>
# <ellipse fill="none" stroke="black" cx="226.03" cy="-383.52" rx="27" ry="18"/>
# <text text-anchor="middle" x="226.03" y="-379.82" font-family="Times,serif" font-size="14.00">4</text>
# </g>
# <!-- n_1&#45;&gt;n_2 -->
# <g id="edge1" class="edge">
# <title>n_1&#45;&gt;n_2</title>
# <path fill="none" stroke="black" d="M226.03,-461.33C226.03,-446.31 226.03,-427.41 226.03,-412.11"/>
# <polygon fill="black" stroke="black" points="229.53,-411.72 226.03,-401.72 222.53,-411.72 229.53,-411.72"/>
# <text text-anchor="middle" x="260.53" y="-432.19" font-family="Times,serif" font-size="14.00">initializer</text>
# </g>
# <!-- n_4 -->
# <g id="node5" class="node">
# <title>n_4</title>
# <ellipse fill="none" stroke="black" cx="429.03" cy="-383.52" rx="141.88" ry="18"/>
# <text text-anchor="middle" x="429.03" y="-379.82" font-family="Times,serif" font-size="14.00">$default_number_of_choices</text>
# </g>
# <!-- n_3&#45;&gt;n_4 -->
# <g id="edge3" class="edge">
# <title>n_3&#45;&gt;n_4</title>
# <path fill="none" stroke="black" d="M441,-461.33C438.63,-446.17 435.66,-427.04 433.26,-411.67"/>
# <polygon fill="black" stroke="black" points="436.71,-411.06 431.71,-401.72 429.79,-412.14 436.71,-411.06"/>
# <text text-anchor="middle" x="472.53" y="-432.19" font-family="Times,serif" font-size="14.00">initializer</text>
# </g>
# <!-- n_6 -->
# <g id="node7" class="node">
# <title>n_6</title>
# <ellipse fill="none" stroke="black" cx="626.03" cy="-383.52" rx="37.45" ry="26.74"/>
# <text text-anchor="middle" x="626.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="626.03" y="-372.32" font-family="Times,serif" font-size="14.00">topic</text>
# </g>
# <!-- n_5&#45;&gt;n_6 -->
# <g id="edge6" class="edge">
# <title>n_5&#45;&gt;n_6</title>
# <path fill="none" stroke="black" d="M1836.06,-486.42C1625.83,-483.61 1002.02,-472.94 801.03,-443.39 742.91,-434.84 727.64,-432.05 673.03,-410.39 669.77,-409.09 666.46,-407.62 663.17,-406.05"/>
# <polygon fill="black" stroke="black" points="664.56,-402.83 654.06,-401.43 661.4,-409.08 664.56,-402.83"/>
# <text text-anchor="middle" x="827.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[0]</text>
# </g>
# <!-- n_8 -->
# <g id="node9" class="node">
# <title>n_8</title>
# <ellipse fill="none" stroke="black" cx="737.03" cy="-383.52" rx="55.31" ry="26.74"/>
# <text text-anchor="middle" x="737.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="737.03" y="-372.32" font-family="Times,serif" font-size="14.00">question</text>
# </g>
# <!-- n_5&#45;&gt;n_8 -->
# <g id="edge8" class="edge">
# <title>n_5&#45;&gt;n_8</title>
# <path fill="none" stroke="black" d="M1836.16,-486.07C1642.53,-482.46 1101.76,-470.2 926.03,-443.39 869.23,-434.72 855.55,-428.52 801.03,-410.39 796.51,-408.88 791.85,-407.22 787.2,-405.49"/>
# <polygon fill="black" stroke="black" points="788.31,-402.16 777.72,-401.85 785.8,-408.7 788.31,-402.16"/>
# <text text-anchor="middle" x="952.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[1]</text>
# </g>
# <!-- n_10 -->
# <g id="node11" class="node">
# <title>n_10</title>
# <ellipse fill="none" stroke="black" cx="859.03" cy="-383.52" rx="48.58" ry="26.74"/>
# <text text-anchor="middle" x="859.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="859.03" y="-372.32" font-family="Times,serif" font-size="14.00">choices</text>
# </g>
# <!-- n_5&#45;&gt;n_10 -->

# %% [markdown]
# ## Reusable data-structure
#
# **Note**:
#  - showing shorthand for single element `return`

# %%
tree = frontend("""
struct a_choice {
    is {
        value   is text;
        correct is bool;
    }
    annotate {
        .value   as "the value of the choice";
        .correct as "you decide whether this choice is correct or not";
    }
}

prompt mmlu_main {
    is {
        topic      is text;
        question   is text;
        choices[4] is a_choice;
        answer     is repeat(.choices.value);
    }
    channel {
        to .topic         from ?topic;
        to .question      from ?question;
        to .choices.value from ?choices;
    }
    return .answer;
    annotate {
        .topic    as "the general category from which the question was taken";
        .question as "the question that you have to answer";
        .choices  as "you judge whether each choice is correct or not";
        .answer   as "you repeat the value of the choice that best answer the question";
    }
}
""")
wrap_graphviz(tree.toGraphViz())
# Out:
#         <div class="svg_container_1198b1be_c9c9_45cb_9d9f_9626f94827d4">
#             <style>
#                 .svg_container_1198b1be_c9c9_45cb_9d9f_9626f94827d4 {
#                     overflow:hidden
#                 }
#                 .svg_container_1198b1be_c9c9_45cb_9d9f_9626f94827d4 SVG {
#                     height:800px
#                 }
#             </style>
#             <script src="https://bumbu.me/svg-pan-zoom/dist/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_1198b1be_c9c9_45cb_9d9f_9626f94827d4 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.01, maxZoom: 1000.});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="5087pt" height="610pt"
#  viewBox="0.00 0.00 5087.03 610.13" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 606.13)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-606.13 5083.03,-606.13 5083.03,4 -4,4"/>
# <!-- n_0 -->
# <g id="node1" class="node">
# <title>n_0</title>
# <ellipse fill="none" stroke="black" cx="1431.03" cy="-584.13" rx="51.19" ry="18"/>
# <text text-anchor="middle" x="1431.03" y="-580.43" font-family="Times,serif" font-size="14.00">Program</text>
# </g>
# <!-- n_1 -->
# <g id="node2" class="node">
# <title>n_1</title>
# <ellipse fill="none" stroke="black" cx="444.03" cy="-488.26" rx="54.39" ry="26.74"/>
# <text text-anchor="middle" x="444.03" y="-492.06" font-family="Times,serif" font-size="14.00">Struct</text>
# <text text-anchor="middle" x="444.03" y="-477.06" font-family="Times,serif" font-size="14.00">a_choice</text>
# </g>
# <!-- n_0&#45;&gt;n_1 -->
# <g id="edge13" class="edge">
# <title>n_0&#45;&gt;n_1</title>
# <path fill="none" stroke="black" d="M1382.09,-578.47C1218.41,-562.9 690.15,-512.66 507.15,-495.26"/>
# <polygon fill="black" stroke="black" points="507.43,-491.77 497.14,-494.31 506.77,-498.74 507.43,-491.77"/>
# <text text-anchor="middle" x="1086.53" y="-536.93" font-family="Times,serif" font-size="14.00">struct[0]</text>
# </g>
# <!-- n_14 -->
# <g id="node15" class="node">
# <title>n_14</title>
# <ellipse fill="none" stroke="black" cx="2571.03" cy="-488.26" rx="70.01" ry="26.74"/>
# <text text-anchor="middle" x="2571.03" y="-492.06" font-family="Times,serif" font-size="14.00">Prompt</text>
# <text text-anchor="middle" x="2571.03" y="-477.06" font-family="Times,serif" font-size="14.00">mmlu_main</text>
# </g>
# <!-- n_0&#45;&gt;n_14 -->
# <g id="edge61" class="edge">
# <title>n_0&#45;&gt;n_14</title>
# <path fill="none" stroke="black" d="M1480.38,-579.06C1659.18,-564.34 2273.97,-513.72 2492.87,-495.69"/>
# <polygon fill="black" stroke="black" points="2493.32,-499.17 2503,-494.86 2492.74,-492.19 2493.32,-499.17"/>
# <text text-anchor="middle" x="2072.53" y="-536.93" font-family="Times,serif" font-size="14.00">prompt[0]</text>
# </g>
# <!-- n_2 -->
# <g id="node3" class="node">
# <title>n_2</title>
# <ellipse fill="none" stroke="black" cx="76.03" cy="-383.52" rx="38.78" ry="26.74"/>
# <text text-anchor="middle" x="76.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="76.03" y="-372.32" font-family="Times,serif" font-size="14.00">value</text>
# </g>
# <!-- n_1&#45;&gt;n_2 -->
# <g id="edge2" class="edge">
# <title>n_1&#45;&gt;n_2</title>
# <path fill="none" stroke="black" d="M397.43,-474.24C326.45,-454.43 192.13,-416.93 121.71,-397.27"/>
# <polygon fill="black" stroke="black" points="122.37,-393.82 111.8,-394.5 120.49,-400.56 122.37,-393.82"/>
# <text text-anchor="middle" x="309.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[0]</text>
# </g>
# <!-- n_4 -->
# <g id="node5" class="node">
# <title>n_4</title>
# <ellipse fill="none" stroke="black" cx="271.03" cy="-383.52" rx="48.17" ry="26.74"/>
# <text text-anchor="middle" x="271.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="271.03" y="-372.32" font-family="Times,serif" font-size="14.00">correct</text>
# </g>
# <!-- n_1&#45;&gt;n_4 -->
# <g id="edge4" class="edge">
# <title>n_1&#45;&gt;n_4</title>
# <path fill="none" stroke="black" d="M409.85,-466.96C381.74,-450.26 341.82,-426.56 312,-408.85"/>
# <polygon fill="black" stroke="black" points="313.48,-405.66 303.1,-403.56 309.91,-411.67 313.48,-405.66"/>
# <text text-anchor="middle" x="394.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[1]</text>
# </g>
# <!-- n_6 -->
# <g id="node7" class="node">
# <title>n_6</title>
# <ellipse fill="none" stroke="black" cx="444.03" cy="-383.52" rx="61.99" ry="18"/>
# <text text-anchor="middle" x="444.03" y="-379.82" font-family="Times,serif" font-size="14.00">Annotation</text>
# </g>
# <!-- n_1&#45;&gt;n_6 -->
# <g id="edge8" class="edge">
# <title>n_1&#45;&gt;n_6</title>
# <path fill="none" stroke="black" d="M444.03,-461.33C444.03,-446.31 444.03,-427.41 444.03,-412.11"/>
# <polygon fill="black" stroke="black" points="447.53,-411.72 444.03,-401.72 440.53,-411.72 447.53,-411.72"/>
# <text text-anchor="middle" x="492.53" y="-432.19" font-family="Times,serif" font-size="14.00">annotation[0]</text>
# </g>
# <!-- n_10 -->
# <g id="node11" class="node">
# <title>n_10</title>
# <ellipse fill="none" stroke="black" cx="646.03" cy="-383.52" rx="61.99" ry="18"/>
# <text text-anchor="middle" x="646.03" y="-379.82" font-family="Times,serif" font-size="14.00">Annotation</text>
# </g>
# <!-- n_1&#45;&gt;n_10 -->
# <g id="edge12" class="edge">
# <title>n_1&#45;&gt;n_10</title>
# <path fill="none" stroke="black" d="M485.33,-470.62C503.82,-462.84 525.76,-453.15 545.03,-443.39 568.01,-431.75 593.03,-417.19 612.41,-405.45"/>
# <polygon fill="black" stroke="black" points="614.45,-408.31 621.17,-400.12 610.81,-402.33 614.45,-408.31"/>
# <text text-anchor="middle" x="619.53" y="-432.19" font-family="Times,serif" font-size="14.00">annotation[1]</text>
# </g>
# <!-- n_3 -->
# <g id="node4" class="node">
# <title>n_3</title>
# <ellipse fill="none" stroke="black" cx="53.03" cy="-268.17" rx="53.07" ry="26.74"/>
# <text text-anchor="middle" x="53.03" y="-271.97" font-family="Times,serif" font-size="14.00">TypeRef</text>
# <text text-anchor="middle" x="53.03" y="-256.97" font-family="Times,serif" font-size="14.00">text</text>
# </g>
# <!-- n_2&#45;&gt;n_3 -->
# <g id="edge1" class="edge">
# <title>n_2&#45;&gt;n_3</title>
# <path fill="none" stroke="black" d="M70.81,-356.8C67.72,-341.54 63.75,-321.97 60.34,-305.2"/>
# <polygon fill="black" stroke="black" points="63.73,-304.29 58.31,-295.18 56.87,-305.68 63.73,-304.29"/>
# <text text-anchor="middle" x="83.03" y="-327.45" font-family="Times,serif" font-size="14.00">type</text>
# </g>
# <!-- n_5 -->
# <g id="node6" class="node">
# <title>n_5</title>
# <ellipse fill="none" stroke="black" cx="177.03" cy="-268.17" rx="53.07" ry="26.74"/>
# <text text-anchor="middle" x="177.03" y="-271.97" font-family="Times,serif" font-size="14.00">TypeRef</text>
# <text text-anchor="middle" x="177.03" y="-256.97" font-family="Times,serif" font-size="14.00">bool</text>
# </g>
# <!-- n_4&#45;&gt;n_5 -->
# <g id="edge3" class="edge">
# <title>n_4&#45;&gt;n_5</title>
# <path fill="none" stroke="black" d="M251.33,-358.76C237.51,-342.09 218.87,-319.62 203.72,-301.35"/>
# <polygon fill="black" stroke="black" points="206.11,-

# %% [markdown]
# ## Flow between prompts and formats
#
# **Note**:
#  - annotation with f-exp `f"{var}"`
#  - global `flow` declares possible entry point
#    - entry point defaults to `main`
#    - if not precised the first prompt defaults to be `main`

# %%
tree = frontend("""
format sentence {
    argument N=30;
    is text<$N>;
    annotate f"A grammatically correct sentence made of at most {N} tokens.";
}

prompt mmlu_main {
    define K=50;
    is {
        topic       is text;
        question    is text;
        hyphothesis is sentence<$K>;
    }
    channel {
        to .topic    from ?topic;
        to .question from ?question;
    }
    flow {
        to mmlu_choose;
    }
}

prompt mmlu_choose {
    is {
        topic       is text;
        question    is text;
        hyphothesis is sentence;
        choices[4]  is text;
        answer      is repeat(.choices.value);
    }
    channel {
        to .topic         from ?topic;
        to .question      from ?question;
        to .choices.value from ?choices;
        to .hyphothesis   from mmlu_main.hyphothesis;
    }
    return .answer;
}

flow {
    to mmlu_main as "main";
}
""")
wrap_graphviz(tree.toGraphViz())
# Out:
#         <div class="svg_container_21221a19_5b18_463d_91e2_68b5fd07a635">
#             <style>
#                 .svg_container_21221a19_5b18_463d_91e2_68b5fd07a635 {
#                     overflow:hidden
#                 }
#                 .svg_container_21221a19_5b18_463d_91e2_68b5fd07a635 SVG {
#                     height:800px
#                 }
#             </style>
#             <script src="https://bumbu.me/svg-pan-zoom/dist/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_21221a19_5b18_463d_91e2_68b5fd07a635 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.01, maxZoom: 1000.});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="3554pt" height="610pt"
#  viewBox="0.00 0.00 3554.03 610.13" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 606.13)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-606.13 3550.03,-606.13 3550.03,4 -4,4"/>
# <!-- n_0 -->
# <g id="node1" class="node">
# <title>n_0</title>
# <ellipse fill="none" stroke="black" cx="1679.03" cy="-584.13" rx="51.19" ry="18"/>
# <text text-anchor="middle" x="1679.03" y="-580.43" font-family="Times,serif" font-size="14.00">Program</text>
# </g>
# <!-- n_1 -->
# <g id="node2" class="node">
# <title>n_1</title>
# <ellipse fill="none" stroke="black" cx="493.03" cy="-488.26" rx="56.64" ry="26.74"/>
# <text text-anchor="middle" x="493.03" y="-492.06" font-family="Times,serif" font-size="14.00">Format</text>
# <text text-anchor="middle" x="493.03" y="-477.06" font-family="Times,serif" font-size="14.00">sentence</text>
# </g>
# <!-- n_0&#45;&gt;n_1 -->
# <g id="edge7" class="edge">
# <title>n_0&#45;&gt;n_1</title>
# <path fill="none" stroke="black" d="M1629.58,-579.21C1441.74,-564.35 772.3,-511.36 558.9,-494.47"/>
# <polygon fill="black" stroke="black" points="559.03,-490.97 548.78,-493.67 558.48,-497.95 559.03,-490.97"/>
# <text text-anchor="middle" x="1262.03" y="-536.93" font-family="Times,serif" font-size="14.00">format[0]</text>
# </g>
# <!-- n_8 -->
# <g id="node9" class="node">
# <title>n_8</title>
# <ellipse fill="none" stroke="black" cx="1398.03" cy="-488.26" rx="70.01" ry="26.74"/>
# <text text-anchor="middle" x="1398.03" y="-492.06" font-family="Times,serif" font-size="14.00">Prompt</text>
# <text text-anchor="middle" x="1398.03" y="-477.06" font-family="Times,serif" font-size="14.00">mmlu_main</text>
# </g>
# <!-- n_0&#45;&gt;n_8 -->
# <g id="edge29" class="edge">
# <title>n_0&#45;&gt;n_8</title>
# <path fill="none" stroke="black" d="M1643.16,-571.14C1596.79,-555.65 1515.36,-528.45 1459.15,-509.67"/>
# <polygon fill="black" stroke="black" points="1460.25,-506.35 1449.66,-506.5 1458.04,-512.99 1460.25,-506.35"/>
# <text text-anchor="middle" x="1608.53" y="-536.93" font-family="Times,serif" font-size="14.00">prompt[0]</text>
# </g>
# <!-- n_30 -->
# <g id="node31" class="node">
# <title>n_30</title>
# <ellipse fill="none" stroke="black" cx="2367.03" cy="-488.26" rx="79.81" ry="26.74"/>
# <text text-anchor="middle" x="2367.03" y="-492.06" font-family="Times,serif" font-size="14.00">Prompt</text>
# <text text-anchor="middle" x="2367.03" y="-477.06" font-family="Times,serif" font-size="14.00">mmlu_choose</text>
# </g>
# <!-- n_0&#45;&gt;n_30 -->
# <g id="edge68" class="edge">
# <title>n_0&#45;&gt;n_30</title>
# <path fill="none" stroke="black" d="M1726.05,-576.71C1841.09,-561.02 2137.94,-520.51 2283.73,-500.62"/>
# <polygon fill="black" stroke="black" points="2284.53,-504.05 2293.96,-499.23 2283.58,-497.11 2284.53,-504.05"/>
# <text text-anchor="middle" x="2080.53" y="-536.93" font-family="Times,serif" font-size="14.00">prompt[1]</text>
# </g>
# <!-- n_69 -->
# <g id="node70" class="node">
# <title>n_69</title>
# <ellipse fill="none" stroke="black" cx="2920.03" cy="-488.26" rx="70.01" ry="26.74"/>
# <text text-anchor="middle" x="2920.03" y="-492.06" font-family="Times,serif" font-size="14.00">Flow</text>
# <text text-anchor="middle" x="2920.03" y="-477.06" font-family="Times,serif" font-size="14.00">mmlu_main</text>
# </g>
# <!-- n_0&#45;&gt;n_69 -->
# <g id="edge70" class="edge">
# <title>n_0&#45;&gt;n_69</title>
# <path fill="none" stroke="black" d="M1728.83,-579.36C1919.96,-564.9 2607.46,-512.9 2841.43,-495.2"/>
# <polygon fill="black" stroke="black" points="2841.85,-498.68 2851.56,-494.44 2841.33,-491.7 2841.85,-498.68"/>
# <text text-anchor="middle" x="2361.03" y="-536.93" font-family="Times,serif" font-size="14.00">flow[0]</text>
# </g>
# <!-- n_2 -->
# <g id="node3" class="node">
# <title>n_2</title>
# <ellipse fill="none" stroke="black" cx="53.03" cy="-383.52" rx="53.07" ry="26.74"/>
# <text text-anchor="middle" x="53.03" y="-387.32" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="53.03" y="-372.32" font-family="Times,serif" font-size="14.00">N</text>
# </g>
# <!-- n_1&#45;&gt;n_2 -->
# <g id="edge2" class="edge">
# <title>n_1&#45;&gt;n_2</title>
# <path fill="none" stroke="black" d="M438.29,-481.46C381.45,-474.8 290.22,-462.28 213.03,-443.39 168.39,-432.46 158.04,-426.58 115.03,-410.39 110.8,-408.8 106.44,-407.09 102.07,-405.35"/>
# <polygon fill="black" stroke="black" points="103.14,-402.01 92.56,-401.5 100.51,-408.5 103.14,-402.01"/>
# <text text-anchor="middle" x="252.03" y="-432.19" font-family="Times,serif" font-size="14.00">variable[0]</text>
# </g>
# <!-- n_4 -->
# <g id="node5" class="node">
# <title>n_4</title>
# <ellipse fill="none" stroke="black" cx="177.03" cy="-383.52" rx="53.07" ry="26.74"/>
# <text text-anchor="middle" x="177.03" y="-387.32" font-family="Times,serif" font-size="14.00">TypeRef</text>
# <text text-anchor="middle" x="177.03" y="-372.32" font-family="Times,serif" font-size="14.00">text</text>
# </g>
# <!-- n_1&#45;&gt;n_4 -->
# <g id="edge5" class="edge">
# <title>n_1&#45;&gt;n_4</title>
# <path fill="none" stroke="black" d="M444.34,-474.11C392.85,-459.83 309.5,-435.68 239.03,-410.39 234.78,-408.86 230.4,-407.2 226.02,-405.49"/>
# <polygon fill="black" stroke="black" points="227.07,-402.15 216.49,-401.68 224.47,-408.64 227.07,-402.15"/>
# <text text-anchor="middle" x="352.03" y="-432.19" font-family="Times,serif" font-size="14.00">type</text>
# </g>
# <!-- n_7 -->
# <g id="node8" class="node">
# <title>n_7</title>
# <ellipse fill="none" stroke="black" cx="565.03" cy="-383.52" rx="316.54" ry="18"/>
# <text text-anchor="middle" x="565.03" y="-379.82" font-family="Times,serif" font-size="14.00">f&quot;A grammatically correct sentence made of at most {N} tokens.&quot;</text>
# </g>
# <!-- n_1&#45;&gt;n_7 -->
# <g id="edge6" class="edge">
# <title>n_1&#45;&gt;n_7</title>
# <path fill="none" stroke="black" d="M510.28,-462.65C521.44,-446.72 535.94,-426.03 547.22,-409.94"/>
# <polygon fill="black" stroke="black" points="550.23,-411.74 553.11,-401.54 544.5,-407.72 550.23,-411.74"/>
# <text text-anchor="middle" x="572.53" y="-432.19" font-family="Times,serif" font-size="14.00">annotation</text>
# </g>
# <!-- n_3 -->
# <g id="node4" class="node">
# <title>n_3</title>
# <ellipse fill="none" stroke="black" cx="53.03" cy="-268.17" rx="27" ry="18"/>
# <text text-anchor="middle" x="53.03" y="-264.47" font-family="Times,serif" font-size="14.00">30</text>
# </g>
# <!-- n_2&#45;&gt;n_3 -->
# <g id="edge1" class="edge">
# <title>n_2&

# %% [markdown]
# ## Iterations
#
# **Note**:
#  - use of `as` in both `flow` and `return`, when prompt ends LLM will have to choose between `retry` and `ready`
#    - without `as` choice would have been `mmlu_main` or `return`
#  - `[5]` in the flow section limits the trip count on that branch ensuring termination

# %%
tree = frontend("""
prompt mmlu_main {
    is {
        topic         is text;
        question      is text;
        choices[4]    is text;
        previous[0:1] is text<20>;
        answer        is repeat(.choices.value);
        reflect       is text<20>;
    }
    channel {
        to .topic         from ?topic;
        to .question      from ?question;
        to .choices.value from ?choices;
        to .previous      from .reflect;
    }
    flow {
        to mmlu_main[5] as "retry";
    }
    return {
        as "ready";
        from .answer;
    }
}
""")
wrap_graphviz(tree.toGraphViz())
# Out:
#         <div class="svg_container_4e3f3087_4913_4591_96f7_56a89687096e">
#             <style>
#                 .svg_container_4e3f3087_4913_4591_96f7_56a89687096e {
#                     overflow:hidden
#                 }
#                 .svg_container_4e3f3087_4913_4591_96f7_56a89687096e SVG {
#                     height:800px
#                 }
#             </style>
#             <script src="https://bumbu.me/svg-pan-zoom/dist/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_4e3f3087_4913_4591_96f7_56a89687096e svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.01, maxZoom: 1000.});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="1974pt" height="610pt"
#  viewBox="0.00 0.00 1974.18 610.13" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 606.13)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-606.13 1970.18,-606.13 1970.18,4 -4,4"/>
# <!-- n_0 -->
# <g id="node1" class="node">
# <title>n_0</title>
# <ellipse fill="none" stroke="black" cx="745.03" cy="-584.13" rx="51.19" ry="18"/>
# <text text-anchor="middle" x="745.03" y="-580.43" font-family="Times,serif" font-size="14.00">Program</text>
# </g>
# <!-- n_1 -->
# <g id="node2" class="node">
# <title>n_1</title>
# <ellipse fill="none" stroke="black" cx="745.03" cy="-488.26" rx="70.01" ry="26.74"/>
# <text text-anchor="middle" x="745.03" y="-492.06" font-family="Times,serif" font-size="14.00">Prompt</text>
# <text text-anchor="middle" x="745.03" y="-477.06" font-family="Times,serif" font-size="14.00">mmlu_main</text>
# </g>
# <!-- n_0&#45;&gt;n_1 -->
# <g id="edge49" class="edge">
# <title>n_0&#45;&gt;n_1</title>
# <path fill="none" stroke="black" d="M745.03,-565.91C745.03,-554.61 745.03,-539.4 745.03,-525.5"/>
# <polygon fill="black" stroke="black" points="748.53,-525.23 745.03,-515.23 741.53,-525.23 748.53,-525.23"/>
# <text text-anchor="middle" x="781.53" y="-536.93" font-family="Times,serif" font-size="14.00">prompt[0]</text>
# </g>
# <!-- n_2 -->
# <g id="node3" class="node">
# <title>n_2</title>
# <ellipse fill="none" stroke="black" cx="55.03" cy="-383.52" rx="37.45" ry="26.74"/>
# <text text-anchor="middle" x="55.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="55.03" y="-372.32" font-family="Times,serif" font-size="14.00">topic</text>
# </g>
# <!-- n_1&#45;&gt;n_2 -->
# <g id="edge2" class="edge">
# <title>n_1&#45;&gt;n_2</title>
# <path fill="none" stroke="black" d="M676.09,-483.58C584.5,-478.06 417.87,-465.81 277.03,-443.39 211.33,-432.93 195.06,-428.46 131.03,-410.39 120.15,-407.31 108.53,-403.59 97.73,-399.93"/>
# <polygon fill="black" stroke="black" points="98.68,-396.56 88.09,-396.62 96.41,-403.18 98.68,-396.56"/>
# <text text-anchor="middle" x="303.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[0]</text>
# </g>
# <!-- n_4 -->
# <g id="node5" class="node">
# <title>n_4</title>
# <ellipse fill="none" stroke="black" cx="195.03" cy="-383.52" rx="55.31" ry="26.74"/>
# <text text-anchor="middle" x="195.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="195.03" y="-372.32" font-family="Times,serif" font-size="14.00">question</text>
# </g>
# <!-- n_1&#45;&gt;n_4 -->
# <g id="edge4" class="edge">
# <title>n_1&#45;&gt;n_4</title>
# <path fill="none" stroke="black" d="M677.01,-481.91C605.37,-475.57 489.53,-463.26 391.03,-443.39 338.07,-432.7 325.72,-426.13 274.03,-410.39 266,-407.94 257.53,-405.27 249.24,-402.6"/>
# <polygon fill="black" stroke="black" points="250.23,-399.24 239.63,-399.48 248.07,-405.9 250.23,-399.24"/>
# <text text-anchor="middle" x="417.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[1]</text>
# </g>
# <!-- n_6 -->
# <g id="node7" class="node">
# <title>n_6</title>
# <ellipse fill="none" stroke="black" cx="332.03" cy="-383.52" rx="48.58" ry="26.74"/>
# <text text-anchor="middle" x="332.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="332.03" y="-372.32" font-family="Times,serif" font-size="14.00">choices</text>
# </g>
# <!-- n_1&#45;&gt;n_6 -->
# <g id="edge6" class="edge">
# <title>n_1&#45;&gt;n_6</title>
# <path fill="none" stroke="black" d="M680.02,-478.25C629.9,-470.7 559.08,-458.7 498.03,-443.39 452.23,-431.9 441.44,-426.46 397.03,-410.39 391.47,-408.37 385.68,-406.19 379.93,-403.98"/>
# <polygon fill="black" stroke="black" points="380.96,-400.62 370.37,-400.24 378.42,-407.14 380.96,-400.62"/>
# <text text-anchor="middle" x="524.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[2]</text>
# </g>
# <!-- n_8 -->
# <g id="node9" class="node">
# <title>n_8</title>
# <ellipse fill="none" stroke="black" cx="461.03" cy="-383.52" rx="55.31" ry="26.74"/>
# <text text-anchor="middle" x="461.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="461.03" y="-372.32" font-family="Times,serif" font-size="14.00">previous</text>
# </g>
# <!-- n_1&#45;&gt;n_8 -->
# <g id="edge10" class="edge">
# <title>n_1&#45;&gt;n_8</title>
# <path fill="none" stroke="black" d="M686.93,-473.24C657.28,-465.5 620.85,-455.09 589.03,-443.39 561.37,-433.21 531.39,-419.57 507.4,-407.98"/>
# <polygon fill="black" stroke="black" points="508.71,-404.72 498.18,-403.49 505.64,-411.01 508.71,-404.72"/>
# <text text-anchor="middle" x="615.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[3]</text>
# </g>
# <!-- n_12 -->
# <g id="node13" class="node">
# <title>n_12</title>
# <ellipse fill="none" stroke="black" cx="586.03" cy="-383.52" rx="48.17" ry="26.74"/>
# <text text-anchor="middle" x="586.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="586.03" y="-372.32" font-family="Times,serif" font-size="14.00">answer</text>
# </g>
# <!-- n_1&#45;&gt;n_12 -->
# <g id="edge15" class="edge">
# <title>n_1&#45;&gt;n_12</title>
# <path fill="none" stroke="black" d="M703.55,-466.33C690.65,-459.42 676.54,-451.43 664.03,-443.39 649.38,-433.96 633.93,-422.63 620.68,-412.43"/>
# <polygon fill="black" stroke="black" points="622.79,-409.63 612.75,-406.26 618.49,-415.16 622.79,-409.63"/>
# <text text-anchor="middle" x="690.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[4]</text>
# </g>
# <!-- n_17 -->
# <g id="node18" class="node">
# <title>n_17</title>
# <ellipse fill="none" stroke="black" cx="699.03" cy="-383.52" rx="44.6" ry="26.74"/>
# <text text-anchor="middle" x="699.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="699.03" y="-372.32" font-family="Times,serif" font-size="14.00">reflect</text>
# </g>
# <!-- n_1&#45;&gt;n_17 -->
# <g id="edge19" class="edge">
# <title>n_1&#45;&gt;n_17</title>
# <path fill="none" stroke="black" d="M733.54,-461.6C727.79,-448.75 720.75,-433.02 714.53,-419.12"/>
# <polygon fill="black" stroke="black" points="717.66,-417.55 710.38,-409.85 711.27,-420.41 717.66,-417.55"/>
# <text text-anchor="middle" x="751.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[5]</text>
# </g>
# <!-- n_21 -->
# <g id="node22" class="node">
# <title>n_21</title>
# <ellipse fill="none" stroke="bl

# %% [markdown]
# ## Calls
#
# **Note**:
#  -

# %%
tree = frontend("""
prompt mmlu_main {
    is {
        topic is text;
        question is text;
        choices[4] is {
            value is text;
            correct is bool;
        }
        answer is repeat(.choices.value);
    }
    channel {
        to .topic    from ?topic;
        to .question from ?question;
        to .choices call {
            entry mmlu_annot;
            kwarg topic    from ?topic;
            kwarg question from ?question;
            kwarg choice   map  ?choices;
            bind choice as value;
        }
    }
    return {
        from .answer;
    }
}

prompt mmlu_annot {
    is {
        topic    is text;
        question is text;
        choice   is text;
        correct  is bool;
    }
    channel {
        to .topic    from ?topic;
        to .question from ?question;
        to .choice   from ?choice;
    }
    return {
        from .choice;
        from .correct;
    }
}
""")
wrap_graphviz(tree.toGraphViz())
# Out:
#         <div class="svg_container_ba7cec6c_c54d_4a3d_96fc_f011f3aaaeb9">
#             <style>
#                 .svg_container_ba7cec6c_c54d_4a3d_96fc_f011f3aaaeb9 {
#                     overflow:hidden
#                 }
#                 .svg_container_ba7cec6c_c54d_4a3d_96fc_f011f3aaaeb9 SVG {
#                     height:800px
#                 }
#             </style>
#             <script src="https://bumbu.me/svg-pan-zoom/dist/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_ba7cec6c_c54d_4a3d_96fc_f011f3aaaeb9 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.01, maxZoom: 1000.});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="2647pt" height="736pt"
#  viewBox="0.00 0.00 2647.03 736.08" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 732.08)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-732.08 2643.03,-732.08 2643.03,4 -4,4"/>
# <!-- n_0 -->
# <g id="node1" class="node">
# <title>n_0</title>
# <ellipse fill="none" stroke="black" cx="1165.03" cy="-710.08" rx="51.19" ry="18"/>
# <text text-anchor="middle" x="1165.03" y="-706.38" font-family="Times,serif" font-size="14.00">Program</text>
# </g>
# <!-- n_1 -->
# <g id="node2" class="node">
# <title>n_1</title>
# <ellipse fill="none" stroke="black" cx="611.03" cy="-614.21" rx="70.01" ry="26.74"/>
# <text text-anchor="middle" x="611.03" y="-618.01" font-family="Times,serif" font-size="14.00">Prompt</text>
# <text text-anchor="middle" x="611.03" y="-603.01" font-family="Times,serif" font-size="14.00">mmlu_main</text>
# </g>
# <!-- n_0&#45;&gt;n_1 -->
# <g id="edge46" class="edge">
# <title>n_0&#45;&gt;n_1</title>
# <path fill="none" stroke="black" d="M1119.7,-701.4C1023.9,-685.17 800.18,-647.26 683.99,-627.57"/>
# <polygon fill="black" stroke="black" points="684.55,-624.12 674.11,-625.9 683.38,-631.02 684.55,-624.12"/>
# <text text-anchor="middle" x="990.53" y="-662.88" font-family="Times,serif" font-size="14.00">prompt[0]</text>
# </g>
# <!-- n_47 -->
# <g id="node48" class="node">
# <title>n_47</title>
# <ellipse fill="none" stroke="black" cx="1731.03" cy="-614.21" rx="73.58" ry="26.74"/>
# <text text-anchor="middle" x="1731.03" y="-618.01" font-family="Times,serif" font-size="14.00">Prompt</text>
# <text text-anchor="middle" x="1731.03" y="-603.01" font-family="Times,serif" font-size="14.00">mmlu_annot</text>
# </g>
# <!-- n_0&#45;&gt;n_47 -->
# <g id="edge77" class="edge">
# <title>n_0&#45;&gt;n_47</title>
# <path fill="none" stroke="black" d="M1210.39,-701.56C1307.25,-685.49 1535.19,-647.69 1654.76,-627.86"/>
# <polygon fill="black" stroke="black" points="1655.64,-631.26 1664.94,-626.17 1654.5,-624.36 1655.64,-631.26"/>
# <text text-anchor="middle" x="1501.53" y="-662.88" font-family="Times,serif" font-size="14.00">prompt[1]</text>
# </g>
# <!-- n_2 -->
# <g id="node3" class="node">
# <title>n_2</title>
# <ellipse fill="none" stroke="black" cx="57.03" cy="-509.47" rx="37.45" ry="26.74"/>
# <text text-anchor="middle" x="57.03" y="-513.27" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="57.03" y="-498.27" font-family="Times,serif" font-size="14.00">topic</text>
# </g>
# <!-- n_1&#45;&gt;n_2 -->
# <g id="edge2" class="edge">
# <title>n_1&#45;&gt;n_2</title>
# <path fill="none" stroke="black" d="M544.11,-606.12C478.75,-598.72 376.63,-585.89 289.03,-569.34 227.92,-557.79 213.29,-551.77 153.03,-536.34 136.14,-532.01 117.63,-527.07 101.41,-522.68"/>
# <polygon fill="black" stroke="black" points="102.21,-519.27 91.64,-520.02 100.37,-526.02 102.21,-519.27"/>
# <text text-anchor="middle" x="315.03" y="-558.14" font-family="Times,serif" font-size="14.00">field[0]</text>
# </g>
# <!-- n_4 -->
# <g id="node5" class="node">
# <title>n_4</title>
# <ellipse fill="none" stroke="black" cx="217.03" cy="-509.47" rx="55.31" ry="26.74"/>
# <text text-anchor="middle" x="217.03" y="-513.27" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="217.03" y="-498.27" font-family="Times,serif" font-size="14.00">question</text>
# </g>
# <!-- n_1&#45;&gt;n_4 -->
# <g id="edge4" class="edge">
# <title>n_1&#45;&gt;n_4</title>
# <path fill="none" stroke="black" d="M547.89,-602.54C504.34,-594.67 445.29,-582.99 394.03,-569.34 351.7,-558.07 304.68,-542.27 269.75,-529.87"/>
# <polygon fill="black" stroke="black" points="270.83,-526.54 260.23,-526.48 268.47,-533.14 270.83,-526.54"/>
# <text text-anchor="middle" x="420.03" y="-558.14" font-family="Times,serif" font-size="14.00">field[1]</text>
# </g>
# <!-- n_6 -->
# <g id="node7" class="node">
# <title>n_6</title>
# <ellipse fill="none" stroke="black" cx="363.03" cy="-509.47" rx="48.58" ry="26.74"/>
# <text text-anchor="middle" x="363.03" y="-513.27" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="363.03" y="-498.27" font-family="Times,serif" font-size="14.00">choices</text>
# </g>
# <!-- n_1&#45;&gt;n_6 -->
# <g id="edge10" class="edge">
# <title>n_1&#45;&gt;n_6</title>
# <path fill="none" stroke="black" d="M557.85,-596.65C534.63,-588.99 507.23,-579.37 483.03,-569.34 457.13,-558.6 428.94,-544.88 406.4,-533.39"/>
# <polygon fill="black" stroke="black" points="407.91,-530.23 397.42,-528.78 404.72,-536.46 407.91,-530.23"/>
# <text text-anchor="middle" x="509.03" y="-558.14" font-family="Times,serif" font-size="14.00">field[2]</text>
# </g>
# <!-- n_12 -->
# <g id="node13" class="node">
# <title>n_12</title>
# <ellipse fill="none" stroke="black" cx="490.03" cy="-509.47" rx="48.17" ry="26.74"/>
# <text text-anchor="middle" x="490.03" y="-513.27" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="490.03" y="-498.27" font-family="Times,serif" font-size="14.00">answer</text>
# </g>
# <!-- n_1&#45;&gt;n_12 -->
# <g id="edge15" class="edge">
# <title>n_1&#45;&gt;n_12</title>
# <path fill="none" stroke="black" d="M580.49,-589.92C572.14,-583.38 563.15,-576.18 555.03,-569.34 543.88,-559.95 531.98,-549.34 521.45,-539.75"/>
# <polygon fill="black" stroke="black" points="523.79,-537.15 514.05,-532.97 519.06,-542.31 523.79,-537.15"/>
# <text text-anchor="middle" x="581.03" y="-558.14" font-family="Times,serif" font-size="14.00">field[3]</text>
# </g>
# <!-- n_17 -->
# <g id="node18" class="node">
# <title>n_17</title>
# <ellipse fill="none" stroke="black" cx="611.03" cy="-509.47" rx="48.99" ry="18"/>
# <text text-anchor="middle" x="611.03" y="-505.77" font-family="Times,serif" font-size="14.00">Channel</text>
# </g>
# <!-- n_1&#45;&gt;n_17 -->
# <g id="edge20" class="edge">
# <title>n_1&#45;&gt;n_17</title>
# <path fill="none" stroke="black" d="M611.03,-587.28C611.03,-572.26 611.03,-553.36 611.03,-538.07"/>
# <polygon fill="black" stroke="black" points="614.53,-537.67 611.03,-527.67 607.53,-537.67 614.53,-537.67"/>
# <text text-anchor="middle" x="649.03" y="-558.14" font-family="Times,serif" font-size="14.00">channel[0]</text>
# </g>
# <!-- n_22 -->
# <g id="node23" class="node">
# <title>n_22</title>
# <ellipse fill="none" stroke="black" cx="729.03" cy="-509.47" rx="48.99" ry="18"/>
# <text text-anchor="middle" x="729.03" y="-505.77" font-family="Times,serif" font-size="14.00">Channel</text>
# </g>
# <!-- n_1&#45;&gt;n_22 -->
# <g id="edge25

# %% [markdown]
# # MMLU Application (WIP)
#
# Goal is to integrate the various pattern define above into a "final" MMLU appication.

# %%
tree = frontend("""
argument N=4;
argument main_trip_count=5;
argument annot_trip_count=3;

format thought {
    argument N=20;
    is text<$N>;
    annotate f"Intermediate thoughts used to reach reflect, at most {N} tokens.";
}

format sentence {
    argument N=50;
    is text<$N>;
    annotate f"A grammatically correct sentence made of at most {N} tokens.";
}

format correctness {
    is enum("yes","no","maybe");
    annotate "Evaluation of the correctness of a statement, can be yes, no, or maybe.";
}

struct a_choice {
    is {
        value   is text;
        correct is correctness;
        comment is sentence;
    }
    annotate {
        .value   as "the value of the choice offered to answer a question";
        .correct as "evaluation of the correctness of that choice";
        .comment as "explaination of the evaluation of this choice";
    }
}

define annot_topic="the general category from which the question was taken";
define annot_question="the question that you have to answer";
define annot_hint="if present, this is a comment you provided earlier to use as a hint";
define annot_reflect="evaluate your answer, does it seem correct?";
define annot_comment="provide a comment to be a hint in your next attempt";

prompt mmlu_main {
    is {
        topic         is text;
        question      is text;
        choices[$N]   is a_choice;
        hint[0:1]     is sentence;
        work[3:10]    is thought;
        answer        is repeat(.choices.value);
        reflect[3:10] is thought;
        comment       is sentence;
    }
    channel {
        to .topic    from ?topic;
        to .question from ?question;
        to .hint     from .comment;
        to .choices call {
            entry mmlu_annot;
            kwarg topic    from ?topic;
            kwarg question from ?question;
            kwarg choice   map  ?choices;
            bind choice as value;
        }
    }
    flow {
        to mmlu_main[$main_trip_count] as "retry";
    }
    return {
        as "ready";
        from .answer;
    }
    annotate {
        .topic    as $annot_topic;
        .question as $annot_question;
        .choices  as f"the {N} choices provided with your judgement of their correctness";
        .hint     as $annot_hint;
        .work     as "think about the choices and decide which one provides the best answer to the question";
        .answer   as "you repeat the value of the choice that best answer the question";
        .reflect  as $annot_reflect;
        .comment  as $annot_comment;
    }
}

prompt mmlu_annot {
    is {
        topic         is text;
        question      is text;
        choice        is text;
        hint[0:1]     is sentence;
        work[3:10]    is thought;
        correct       is correctness;
        reflect[3:10] is thought;
        comment       is sentence;
    }
    channel {
        to .topic    from ?topic;
        to .question from ?question;
        to .choice   from ?choice;
        to .hint     from .comment;
    }
    flow {
        to mmlu_annot[$annot_trip_count] as "retry";
    }
    return {
        as "ready";
        from .choice;
        from .correct;
        from .comment;
    }
    annotate {
        .topic    as $annot_topic;
        .question as $annot_question;
        .choice   as "one of the {N} choices provided which may be the best answer to the question";
        .hint     as $annot_hint;
        .work     as "think about this choice and decide whether it could answer the question";
        .correct as "evaluation of the correctness of that choice";
        .reflect  as $annot_reflect;
        .comment  as $annot_comment;
    }
}
""")
wrap_graphviz(tree.toGraphViz())
# Out:
#         <div class="svg_container_cef0ffbf_d8a1_43b9_9812_b4c27add5640">
#             <style>
#                 .svg_container_cef0ffbf_d8a1_43b9_9812_b4c27add5640 {
#                     overflow:hidden
#                 }
#                 .svg_container_cef0ffbf_d8a1_43b9_9812_b4c27add5640 SVG {
#                     height:800px
#                 }
#             </style>
#             <script src="https://bumbu.me/svg-pan-zoom/dist/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_cef0ffbf_d8a1_43b9_9812_b4c27add5640 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.01, maxZoom: 1000.});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="19835pt" height="736pt"
#  viewBox="0.00 0.00 19835.18 736.08" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 732.08)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-732.08 19831.18,-732.08 19831.18,4 -4,4"/>
# <!-- n_0 -->
# <g id="node1" class="node">
# <title>n_0</title>
# <ellipse fill="none" stroke="black" cx="2508.03" cy="-710.08" rx="51.19" ry="18"/>
# <text text-anchor="middle" x="2508.03" y="-706.38" font-family="Times,serif" font-size="14.00">Program</text>
# </g>
# <!-- n_1 -->
# <g id="node2" class="node">
# <title>n_1</title>
# <ellipse fill="none" stroke="black" cx="53.03" cy="-614.21" rx="53.07" ry="26.74"/>
# <text text-anchor="middle" x="53.03" y="-618.01" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="53.03" y="-603.01" font-family="Times,serif" font-size="14.00">N</text>
# </g>
# <!-- n_0&#45;&gt;n_1 -->
# <g id="edge2" class="edge">
# <title>n_0&#45;&gt;n_1</title>
# <path fill="none" stroke="black" d="M2457.08,-707.67C2300.58,-703.28 1812.97,-689.28 1409.03,-674.08 910.47,-655.32 309.04,-627.32 115.93,-618.2"/>
# <polygon fill="black" stroke="black" points="115.85,-614.69 105.69,-617.72 115.52,-621.68 115.85,-614.69"/>
# <text text-anchor="middle" x="1448.03" y="-662.88" font-family="Times,serif" font-size="14.00">variable[0]</text>
# </g>
# <!-- n_3 -->
# <g id="node4" class="node">
# <title>n_3</title>
# <ellipse fill="none" stroke="black" cx="884.03" cy="-614.21" rx="92.76" ry="26.74"/>
# <text text-anchor="middle" x="884.03" y="-618.01" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="884.03" y="-603.01" font-family="Times,serif" font-size="14.00">main_trip_count</text>
# </g>
# <!-- n_0&#45;&gt;n_3 -->
# <g id="edge4" class="edge">
# <title>n_0&#45;&gt;n_3</title>
# <path fill="none" stroke="black" d="M2457.31,-707.28C2332.08,-702.75 1998.25,-690.05 1720.03,-674.08 1453.35,-658.77 1139.2,-635.14 982.83,-623"/>
# <polygon fill="black" stroke="black" points="983,-619.5 972.76,-622.22 982.46,-626.48 983,-619.5"/>
# <text text-anchor="middle" x="1759.03" y="-662.88" font-family="Times,serif" font-size="14.00">variable[1]</text>
# </g>
# <!-- n_5 -->
# <g id="node6" class="node">
# <title>n_5</title>
# <ellipse fill="none" stroke="black" cx="1425.03" cy="-614.21" rx="96.75" ry="26.74"/>
# <text text-anchor="middle" x="1425.03" y="-618.01" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="1425.03" y="-603.01" font-family="Times,serif" font-size="14.00">annot_trip_count</text>
# </g>
# <!-- n_0&#45;&gt;n_5 -->
# <g id="edge6" class="edge">
# <title>n_0&#45;&gt;n_5</title>
# <path fill="none" stroke="black" d="M2457.5,-706.8C2358.86,-702.15 2133.81,-690.62 1945.03,-674.08 1797.22,-661.13 1626.38,-640.74 1522.04,-627.68"/>
# <polygon fill="black" stroke="black" points="1522.2,-624.17 1511.84,-626.4 1521.33,-631.12 1522.2,-624.17"/>
# <text text-anchor="middle" x="1984.03" y="-662.88" font-family="Times,serif" font-size="14.00">variable[2]</text>
# </g>
# <!-- n_7 -->
# <g id="node8" class="node">
# <title>n_7</title>
# <ellipse fill="none" stroke="black" cx="1777.03" cy="-614.21" rx="70.01" ry="26.74"/>
# <text text-anchor="middle" x="1777.03" y="-618.01" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="1777.03" y="-603.01" font-family="Times,serif" font-size="14.00">annot_topic</text>
# </g>
# <!-- n_0&#45;&gt;n_7 -->
# <g id="edge8" class="edge">
# <title>n_0&#45;&gt;n_7</title>
# <path fill="none" stroke="black" d="M2458.1,-705.84C2384.25,-700.75 2241.61,-689.82 2121.03,-674.08 2026.26,-661.71 1917.67,-642.23 1848.28,-629.1"/>
# <polygon fill="black" stroke="black" points="1848.81,-625.64 1838.33,-627.21 1847.5,-632.52 1848.81,-625.64"/>
# <text text-anchor="middle" x="2160.03" y="-662.88" font-family="Times,serif" font-size="14.00">variable[3]</text>
# </g>
# <!-- n_9 -->
# <g id="node10" class="node">
# <title>n_9</title>
# <ellipse fill="none" stroke="black" cx="2036.03" cy="-614.21" rx="88.28" ry="26.74"/>
# <text text-anchor="middle" x="2036.03" y="-618.01" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="2036.03" y="-603.01" font-family="Times,serif" font-size="14.00">annot_question</text>
# </g>
# <!-- n_0&#45;&gt;n_9 -->
# <g id="edge10" class="edge">
# <title>n_0&#45;&gt;n_9</title>
# <path fill="none" stroke="black" d="M2460.02,-703.67C2411.01,-697.79 2332.85,-687.42 2266.03,-674.08 2212.94,-663.48 2153.77,-648.25 2108.75,-635.95"/>
# <polygon fill="black" stroke="black" points="2109.64,-632.56 2099.07,-633.29 2107.79,-639.31 2109.64,-632.56"/>
# <text text-anchor="middle" x="2305.03" y="-662.88" font-family="Times,serif" font-size="14.00">variable[4]</text>
# </g>
# <!-- n_11 -->
# <g id="node12" class="node">
# <title>n_11</title>
# <ellipse fill="none" stroke="black" cx="2249.03" cy="-614.21" rx="65.11" ry="26.74"/>
# <text text-anchor="middle" x="2249.03" y="-618.01" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="2249.03" y="-603.01" font-family="Times,serif" font-size="14.00">annot_hint</text>
# </g>
# <!-- n_0&#45;&gt;n_11 -->
# <g id="edge12" class="edge">
# <title>n_0&#45;&gt;n_11</title>
# <path fill="none" stroke="black" d="M2467.52,-698.84C2443.58,-692.44 2412.81,-683.63 2386.03,-674.08 2357.28,-663.82 2325.94,-650.52 2300.5,-639.16"/>
# <polygon fill="black" stroke="black" points="2301.62,-635.82 2291.06,-634.91 2298.74,-642.21 2301.62,-635.82"/>
# <text text-anchor="middle" x="2425.03" y="-662.88" font-family="Times,serif" font-size="14.00">variable[5]</text>
# </g>
# <!-- n_13 -->
# <g id="node14" class="node">
# <title>n_13</title>
# <ellipse fill="none" stroke="black" cx="2431.03" cy="-614.21" rx="77.56" ry="26.74"/>
# <text text-anchor="middle" x="2431.03" y="-618.01" font-family="Times,serif" font-size="14.00">Variable</text>
# <text text-anchor="middle" x="2431.03" y="-603.01" font-family="Times,serif" font-size="14.00">annot_reflect</text>
# </g>
# <!-- n_0&#45;&gt;n_13 -->
# <g id="edge14" class="edge">
# <title>n_0&#45;&gt;n_13</title>
# <path fill="none" stroke="black" d="M2494.27,-692.3C2484.27,-680.11 2470.4,-663.21 2458.21,-648.34"/>
# <polygon fill="black" stroke="black" points="2460.69,-645.84 2451.64,-640.33 2455.27,-650.28 2460.69,-645.84"/>
# <text text-anchor="middle" x="2518.03" y="-662.88" font-family="Times,serif" font-size="14.00">variable[6]</text>
# </g>
# <!-- n_15 -->
# <g id="node1
