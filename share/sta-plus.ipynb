# %%
import os, sys, json
sys.path.append("/home/tristan/projects/LLM/AutoCog")
from autocog.language.sta.frontend import frontend
from autocog.utility.pynb import wrap_graphviz, display
# Out:
# Warning: Package `llama_cpp` needed for LLaMa wrapper (pip install git+https://github.com/tristanvdb/llama-cpp-python@choice-dev)

# %% [markdown]
# ## Single prompt and _compact_
#
# **Note**:
#  - `text` is implicitly `text<INF>` (meaning no limit on number of tokens)
#    - **but** can only be used if target of a channel

# %%
tree = frontend("""
prompt mmlu_main {
    define default_number_of_choices=4;
    argument N=$default_number_of_choices;
    is {
        topic is text;
        question is text;
        choices[$N] is {
            value is text;
            correct is bool;
        }
        answer is repeat(.choices.value);
    }
    channel {
        to .topic         from ?topic;
        to .question      from ?question;
        to .choices.value from ?choices;
    }
    return {
        from .answer;
    }
    annotate {
        .topic           as "the general category from which the question was taken";
        .question        as "the question that you have to answer";
        .choices         as "you judge whether each choice is correct or not";
        .choices.value   as "the value of the choice";
        .choices.correct as "you decide whether this choice is correct or not";
        .answer          as "you repeat the value of the choice that best answer the question";
    }
}
""")
wrap_graphviz(tree.toGraphViz())
# Out:
#         <div class="svg_container_f842ac95_0b7e_48f8_86e3_a694c0520983">
#             <style>
#                 .svg_container_f842ac95_0b7e_48f8_86e3_a694c0520983 {
#                     overflow:hidden
#                 }
#                 .svg_container_f842ac95_0b7e_48f8_86e3_a694c0520983 SVG {
#                     height:800px
#                 }
#             </style>
#             <script src="https://bumbu.me/svg-pan-zoom/dist/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_f842ac95_0b7e_48f8_86e3_a694c0520983 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.01, maxZoom: 1000.});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="1347pt" height="610pt"
#  viewBox="0.00 0.00 1347.03 610.13" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 606.13)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-606.13 1343.03,-606.13 1343.03,4 -4,4"/>
# <!-- n_0 -->
# <g id="node1" class="node">
# <title>n_0</title>
# <ellipse fill="none" stroke="black" cx="473.03" cy="-584.13" rx="51.19" ry="18"/>
# <text text-anchor="middle" x="473.03" y="-580.43" font-family="Times,serif" font-size="14.00">Program</text>
# </g>
# <!-- n_1 -->
# <g id="node2" class="node">
# <title>n_1</title>
# <ellipse fill="none" stroke="black" cx="473.03" cy="-488.26" rx="70.01" ry="26.74"/>
# <text text-anchor="middle" x="473.03" y="-492.06" font-family="Times,serif" font-size="14.00">Prompt</text>
# <text text-anchor="middle" x="473.03" y="-477.06" font-family="Times,serif" font-size="14.00">mmlu_main</text>
# </g>
# <!-- n_0&#45;&gt;n_1 -->
# <g id="edge36" class="edge">
# <title>n_0&#45;&gt;n_1</title>
# <path fill="none" stroke="black" d="M473.03,-565.91C473.03,-554.61 473.03,-539.4 473.03,-525.5"/>
# <polygon fill="black" stroke="black" points="476.53,-525.23 473.03,-515.23 469.53,-525.23 476.53,-525.23"/>
# <text text-anchor="middle" x="509.53" y="-536.93" font-family="Times,serif" font-size="14.00">prompt[0]</text>
# </g>
# <!-- n_2 -->
# <g id="node3" class="node">
# <title>n_2</title>
# <ellipse fill="none" stroke="black" cx="64.03" cy="-383.52" rx="37.45" ry="26.74"/>
# <text text-anchor="middle" x="64.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="64.03" y="-372.32" font-family="Times,serif" font-size="14.00">topic</text>
# </g>
# <!-- n_1&#45;&gt;n_2 -->
# <g id="edge2" class="edge">
# <title>n_1&#45;&gt;n_2</title>
# <path fill="none" stroke="black" d="M407.77,-478.41C356.8,-470.88 284.4,-458.85 222.03,-443.39 175.79,-431.92 164.41,-427.74 120.03,-410.39 114.8,-408.34 109.35,-406.04 104.01,-403.69"/>
# <polygon fill="black" stroke="black" points="105.11,-400.34 94.56,-399.42 102.23,-406.73 105.11,-400.34"/>
# <text text-anchor="middle" x="248.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[0]</text>
# </g>
# <!-- n_4 -->
# <g id="node5" class="node">
# <title>n_4</title>
# <ellipse fill="none" stroke="black" cx="184.03" cy="-383.52" rx="55.31" ry="26.74"/>
# <text text-anchor="middle" x="184.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="184.03" y="-372.32" font-family="Times,serif" font-size="14.00">question</text>
# </g>
# <!-- n_1&#45;&gt;n_4 -->
# <g id="edge4" class="edge">
# <title>n_1&#45;&gt;n_4</title>
# <path fill="none" stroke="black" d="M414.57,-473.46C384.23,-465.71 346.75,-455.23 314.03,-443.39 285.73,-433.15 255.02,-419.37 230.55,-407.72"/>
# <polygon fill="black" stroke="black" points="232.03,-404.54 221.5,-403.37 229,-410.85 232.03,-404.54"/>
# <text text-anchor="middle" x="340.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[1]</text>
# </g>
# <!-- n_6 -->
# <g id="node7" class="node">
# <title>n_6</title>
# <ellipse fill="none" stroke="black" cx="308.03" cy="-383.52" rx="48.58" ry="26.74"/>
# <text text-anchor="middle" x="308.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="308.03" y="-372.32" font-family="Times,serif" font-size="14.00">choices</text>
# </g>
# <!-- n_1&#45;&gt;n_6 -->
# <g id="edge10" class="edge">
# <title>n_1&#45;&gt;n_6</title>
# <path fill="none" stroke="black" d="M431.04,-466.48C417.71,-459.51 403.06,-451.45 390.03,-443.39 374.61,-433.84 358.25,-422.38 344.24,-412.13"/>
# <polygon fill="black" stroke="black" points="345.97,-409.05 335.84,-405.93 341.81,-414.68 345.97,-409.05"/>
# <text text-anchor="middle" x="416.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[2]</text>
# </g>
# <!-- n_12 -->
# <g id="node13" class="node">
# <title>n_12</title>
# <ellipse fill="none" stroke="black" cx="424.03" cy="-383.52" rx="48.17" ry="26.74"/>
# <text text-anchor="middle" x="424.03" y="-387.32" font-family="Times,serif" font-size="14.00">Field</text>
# <text text-anchor="middle" x="424.03" y="-372.32" font-family="Times,serif" font-size="14.00">answer</text>
# </g>
# <!-- n_1&#45;&gt;n_12 -->
# <g id="edge15" class="edge">
# <title>n_1&#45;&gt;n_12</title>
# <path fill="none" stroke="black" d="M460.79,-461.6C454.67,-448.75 447.16,-433.02 440.54,-419.12"/>
# <polygon fill="black" stroke="black" points="443.58,-417.37 436.12,-409.85 437.26,-420.38 443.58,-417.37"/>
# <text text-anchor="middle" x="478.03" y="-432.19" font-family="Times,serif" font-size="14.00">field[3]</text>
# </g>
# <!-- n_17 -->
# <g id="node18" class="node">
# <title>n_17</title>
# <ellipse fill="none" stroke="black" cx="541.03" cy="-383.52" rx="48.99" ry="18"/>
# <text text-anchor="middle" x="541.03" y="-379.82" font-family="Times,serif" font-size="14.00">Channel</text>
# </g>
# <!-- n_1&#45;&gt;n_17 -->
# <g id="edge20" class="edge">
# <title>n_1&#45;&gt;n_17</title>
# <path fill="none" stroke="black" d="M494.11,-462.27C498.89,-456.23 503.79,-449.69 508.03,-443.39 515.04,-432.97 521.97,-420.95 527.65,-410.5"/>
# <polygon fill="black" stroke="black" points="530.87,-411.91 532.49,-401.44 524.69,-408.62 530.87,-411.91"/>
# <text text-anchor="middle" x="555.03" y="-432.19" font-family="Times,serif" font-size="14.00">channel[0]</text>
# </g>
# <!-- n_22 -->
# <g id="node23" class="node">
# <title>n_22</title>
# <ellipse fill="none" stroke="black" cx="729.03" cy="-383.52" rx="48.99" ry="18"/>
# <text text-anchor="middle" x="729.03" y="-379.82" font-family="Times,serif" font-size="14.00">Channel</text>
# </g>
# <!-- n_1&#45;&gt;n_22 -->
# <g id="edge25" class="edge">
# <title>n_1&#45;&gt;n_22</title>
# <path fill="none" stroke="black" d="M524.65,-470.02C547.05,-462.28 573.49,-452.78 597.03,-443.39 629.1,-430.59 664.83,-414.54 691.02,-402.43"/>
# <polygon fill="black" stroke="black" points="692.62,-405.55 700.22,-398.16 689.67,-399.2 692.62,-405.55"/>
# <text text-anchor="middle" x="668.03" y="-432.19" font-family="Times,serif" font-size="14.00">channel[1]</text>
# </g>
# <!-- n_27 -->
# <g id="node28" class="node">
# <title>n_27</title>
# <ellipse fill="none" stroke="black" cx="1014.03" cy="-383.52" rx="48.99" ry="18"/>
# <text text-anchor="middle" x="1014.03" y="-379.82" font-family="Times,serif" font-size="14.00">Channel</text>
# </g>
# <!-- n_1&#45;&gt;n_27 -->
# <g id="edge31" class="edge">
# <title>n_1&#45;&gt;n_27</title>
# <path fill="none" stroke="black" d="M53

# %% [markdown]
# ## Reusable data-structure
#
# **Note**:
#  - showing shorthand for single element `return`

# %%
tree = frontend("""
struct a_choice {
    is {
        value   is text;
        correct is bool;
    }
    annotate {
        .value   as "the value of the choice";
        .correct as "you decide whether this choice is correct or not";
    }
}

prompt mmlu_main {
    is {
        topic      is text;
        question   is text;
        choices[4] is a_choice;
        answer     is repeat(.choices.value);
    }
    channel {
        to .topic         from ?topic;
        to .question      from ?question;
        to .choices.value from ?choices;
    }
    return .answer;
    annotate {
        .topic    as "the general category from which the question was taken";
        .question as "the question that you have to answer";
        .choices  as "you judge whether each choice is correct or not";
        .answer   as "you repeat the value of the choice that best answer the question";
    }
}
""")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/parsimonious/nodes.py:213, in NodeVisitor.visit(self, node)
#     212 try:
# --> 213     return method(node, [self.visit(n) for n in node])
#     214 except (VisitationError, UndefinedLabel):
#     215     # Don't catch and re-wrap already-wrapped exceptions.
#
# File ~/projects/LLM/AutoCog/autocog/language/sta/frontend.py:22, in Visitor.visit_program(self, node, visited_children)
#      21     else:
# ---> 22         raise Exception(f"Unknown: {child}")
#      23 return program
#
# Exception: Unknown: {'kind': 'struct_decl', 'children': [{'kind': 'STRUCT', 'text': 'struct'}, {'kind': 'WS', 'text': ' '}, {'kind': 'identifier', 'text': 'a_choice'}, {'kind': 'WS', 'text': ' '}, {'kind': 'LCB', 'text': '{'}, {'kind': 'var_decls', 'text': ''}, {'kind': 'WS', 'text': '\n    '}, {'kind': 'field_decls', 'children': [Field(name='value', type=TypeRef(name='text', arguments=[])), Field(name='correct', type=TypeRef(name='bool', arguments=[]))]}, {'kind': 'WS', 'text': '\n    '}, {'kind': '', 'children': [{'kind': 'annot_block', 'children': [{'kind': 'ANNOTATE', 'text': 'annotate'}, {'kind': 'WS', 'text': ' '}, {'kind': 'LCB', 'text': '{'}, {'kind': 'WS', 'text': '\n        '}, {'kind': '', 'children': [{'kind': 'annot_stmt__', 'children': [{'kind': 'annot_stmt', 'children': [Path(steps=[Step(name='value', slice=None)], is_input=False, prompt=None), {'kind': 'WS', 'text': '   '}, {'kind': 'AS', 'text': 'as'}, {'kind': 'WS', 'text': ' '}, Value(value='the value of the choice', is_fstring=False), {'kind': 'SC', 'text': ';'}]}, {'kind': 'WS', 'text': '\n        '}]}, {'kind': 'annot_stmt__', 'children': [{'kind': 'annot_stmt', 'children': [Path(steps=[Step(name='correct', slice=None)], is_input=False, prompt=None), {'kind': 'WS', 'text': ' '}, {'kind': 'AS', 'text': 'as'}, {'kind': 'WS', 'text': ' '}, Value(value='you decide whether this choice is correct or not', is_fstring=False), {'kind': 'SC', 'text': ';'}]}, {'kind': 'WS', 'text': '\n    '}]}]}, {'kind': 'RCB', 'text': '}'}]}]}, {'kind': 'WS', 'text': '\n'}, {'kind': 'RCB', 'text': '}'}]}
#
# The above exception was the direct cause of the following exception:
#
# VisitationError                           Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 tree = frontend("""
#       2 struct a_choice {
#       3     is {
#       4         value   is text;
#       5         correct is bool;
#       6     }
#       7     annotate {
#       8         .value   as "the value of the choice";
#       9         .correct as "you decide whether this choice is correct or not";
#      10     }
#      11 }
#      12
#      13 prompt mmlu_main {
#      14     is {
#      15         topic      is text;
#      16         question   is text;
#      17         choices[4] is a_choice;
#      18         answer     is repeat(.choices.value);
#      19     }
#      20     channel {
#      21         to .topic         from ?topic;
#      22         to .question      from ?question;
#      23         to .choices.value from ?choices;
#      24     }
#      25     return .answer;
#      26     annotate {
#      27         .topic    as "the general category from which the question was taken";
#      28         .question as "the question that you have to answer";
#      29         .choices  as "you judge whether each choice is correct or not";
#      30         .answer   as "you repeat the value of the choice that best answer the question";
#      31     }
#      32 }
#      33 """)
#
# File ~/projects/LLM/AutoCog/autocog/language/sta/frontend.py:474, in frontend(program)
#     472 def frontend(program:str):
#     473     visitor = Visitor()
# --> 474     return visitor.visit(grammar.parse(program))
#
# File ~/.local/lib/python3.8/site-packages/parsimonious/nodes.py:225, in NodeVisitor.visit(self, node)
#     222 # Catch any exception, and tack on a parse tree so it's easier to
#     223 # see where it went wrong.
#     224 exc_class = type(exc)
# --> 225 raise VisitationError(exc, exc_class, node) from exc
#
# VisitationError: Exception: Unknown: {'kind': 'struct_decl', 'children': [{'kind': 'STRUCT', 'text': 'struct'}, {'kind': 'WS', 'text': ' '}, {'kind': 'identifier', 'text': 'a_choice'}, {'kind': 'WS', 'text': ' '}, {'kind': 'LCB', 'text': '{'}, {'kind': 'var_decls', 'text': ''}, {'kind': 'WS', 'text': '\n    '}, {'kind': 'field_decls', 'children': [Field(name='value', type=TypeRef(name='text', arguments=[])), Field(name='correct', type=TypeRef(name='bool', arguments=[]))]}, {'kind': 'WS', 'text': '\n    '}, {'kind': '', 'children': [{'kind': 'annot_block', 'children': [{'kind': 'ANNOTATE', 'text': 'annotate'}, {'kind': 'WS', 'text': ' '}, {'kind': 'LCB', 'text': '{'}, {'kind': 'WS', 'text': '\n        '}, {'kind': '', 'children': [{'kind': 'annot_stmt__', 'children': [{'kind': 'annot_stmt', 'children': [Path(steps=[Step(name='value', slice=None)], is_input=False, prompt=None), {'kind': 'WS', 'text': '   '}, {'kind': 'AS', 'text': 'as'}, {'kind': 'WS', 'text': ' '}, Value(value='the value of the choice', is_fstring=False), {'kind': 'SC', 'text': ';'}]}, {'kind': 'WS', 'text': '\n        '}]}, {'kind': 'annot_stmt__', 'children': [{'kind': 'annot_stmt', 'children': [Path(steps=[Step(name='correct', slice=None)], is_input=False, prompt=None), {'kind': 'WS', 'text': ' '}, {'kind': 'AS', 'text': 'as'}, {'kind': 'WS', 'text': ' '}, Value(value='you decide whether this choice is correct or not', is_fstring=False), {'kind': 'SC', 'text': ';'}]}, {'kind': 'WS', 'text': '\n    '}]}]}, {'kind': 'RCB', 'text': '}'}]}]}, {'kind': 'WS', 'text': '\n'}, {'kind': 'RCB', 'text': '}'}]}
#
# Parse tree:
# <Node called "program" matching "
# struct a_choice {
#     is {
#         value   is text;
#         correct is bool;
#     }
#     annotate {
#         .value   as "the value of the choice";
#         .correct as "you decide whether this choice is correct or not";
#     }
# }
#
# prompt mmlu_main {
#     is {
#         topic      is text;
#         question   is text;
#         choices[4] is a_choice;
#         answer     is repeat(.choices.value);
#     }
#     channel {
#         to .topic         from ?topic;
#         to .question      from ?question;
#         to .choices.value from ?choices;
#     }
#     return .answer;
#     annotate {
#         .topic    as "the general category from which the question was taken";
#         .question as "the question that you have to answer";
#         .choices  as "you judge whether each choice is correct or not";
#         .answer   as "you repeat the value of the choice that best answer the question";
#     }
# }
# ">  <-- *** We were here. ***
#     <Node matching "
#     struct a_choice {
#         is {
#             value   is text;
#             correct is bool;
#         }
#         annotate {
#             .value   as "the value of the choice";
#             .correct as "you decide whether this choice is correct or not";
#         }
#     }
#
#     prompt mmlu_main {
#         is {
#             topic      is text;
#             question   is text;
#             choices[4] is a_choice;
#             answer     is repeat(.choices.value);
#         }
#         channel {
#             to .topic         from ?topic;
#             to .question      from ?question;
#             to .choices.value from ?choices;
#         }
#         return .answer;
#         annotate {
#             .topic    as "the general category from which the question was taken";
#             .question as "the question that you have to answer";
#             .choices  as "you judge whether each choice is correct or not";
#             .answer   as "you repeat the value of the choice that best answer the question";
#         }
#     }">
#         <Node called "declaration__" matching "
#         struct a_choice {
#             is {
#                 value   is text;
#                 correct is bool;
#             }
#             annotate {
#                 .value   as "the value of the choice";
#                 .correct as "you decide whether this choice is correct or not";
#             }
#         }">
#             <RegexNode called "WS" matching "
#             ">
#             <Node called "declaration" matching "struct a_choice {
#                 is {
#                     value   is text;
#                     correct is bool;
#                 }
#                 annotate {
#                     .value   as "the value of the choice";
#                     .correct as "you decide whether this choice is correct or not";
#                 }
#             }">
#                 <Node called "struct_decl" matching "struct a_choice {
#                     is {
#                         value   is text;
#                         correct is bool;
#                     }
#                     annotate {
#                         .value   as "the value of the choice";
#                         .correct as "you decide whether this choice is correct or not";
#                     }
#                 }">
#                     <Node called "STRUCT" matching "struct">
#                     <RegexNode called "WS" matching " ">
#                     <RegexNode called "identifier" matching "a_choice">
#                     <RegexNode called "WS" matching " ">
#                     <Node called "LCB" matching "{">
#                     <Node called "var_decls" matching "">
#                     <RegexNode called "WS" matching "
#                         ">
#                     <Node called "is_record_field" matching "is {
#                             value   is text;
#                             correct is bool;
#                         }">
#                         <Node called "IS" matching "is">
#                         <RegexNode called "WS" matching " ">
#                         <Node called "LCB" matching "{">
#                         <Node called "field_decls" matching "
#                                 value   is text;
#                                 correct is bool;
#                             ">
#                             <Node called "field_decl__" matching "
#                                     value   is text;
#                                     ">
#                                 <RegexNode called "WS" matching "
#                                         ">
#                                 <Node called "field_decl" matching "value   is text;
#                                         ">
#                                     <Node called "field_name" matching "value">
#                                         <RegexNode called "identifier" matching "value">
#                                         <Node matching "">
#                                     <RegexNode called "WS" matching "   ">
#                                     <Node called "field_defn" matching "is text;">
#                                         <Node called "is_format_field" matching "is text;">
#                                             <Node called "IS" matching "is">
#                                             <RegexNode called "WS" matching " ">
#                                             <Node matching "text">
#                                                 <Node called "type_ref" matching "text">
#                                                     <RegexNode called "identifier" matching "text">
#                                                     <RegexNode called "WS" matching "">
#                                                     <Node matching "">
#                                             <RegexNode called "WS" matching "">
#                                             <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                             <Node called "field_decl__" matching "correct is bool;
#                                 ">
#                                 <RegexNode called "WS" matching "">
#                                 <Node called "field_decl" matching "correct is bool;
#                                     ">
#                                     <Node called "field_name" matching "correct">
#                                         <RegexNode called "identifier" matching "correct">
#                                         <Node matching "">
#                                     <RegexNode called "WS" matching " ">
#                                     <Node called "field_defn" matching "is bool;">
#                                         <Node called "is_format_field" matching "is bool;">
#                                             <Node called "IS" matching "is">
#                                             <RegexNode called "WS" matching " ">
#                                             <Node matching "bool">
#                                                 <Node called "type_ref" matching "bool">
#                                                     <RegexNode called "identifier" matching "bool">
#                                                     <RegexNode called "WS" matching "">
#                                                     <Node matching "">
#                                             <RegexNode called "WS" matching "">
#                                             <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                         ">
#                         <RegexNode called "WS" matching "">
#                         <Node called "RCB" matching "}">
#                     <RegexNode called "WS" matching "
#                         ">
#                     <Node matching "annotate {
#                             .value   as "the value of the choice";
#                             .correct as "you decide whether this choice is correct or not";
#                         }">
#                         <Node called "annot_block" matching "annotate {
#                                 .value   as "the value of the choice";
#                                 .correct as "you decide whether this choice is correct or not";
#                             }">
#                             <Node called "ANNOTATE" matching "annotate">
#                             <RegexNode called "WS" matching " ">
#                             <Node called "LCB" matching "{">
#                             <RegexNode called "WS" matching "
#                                     ">
#                             <Node matching ".value   as "the value of the choice";
#                                     .correct as "you decide whether this choice is correct or not";
#                                 ">
#                                 <Node called "annot_stmt__" matching ".value   as "the value of the choice";
#                                         ">
#                                     <Node called "annot_stmt" matching ".value   as "the value of the choice";">
#                                         <Node called "path_expr" matching ".value">
#                                             <Node called "local_path_expr" matching ".value">
#                                                 <Node called "PERIOD" matching ".">
#                                                 <Node called "sub_path_expr" matching "value">
#                                                     <Node called "path_step" matching "value">
#                                                         <RegexNode called "identifier" matching "value">
#                                                         <Node matching "">
#                                                     <Node matching "">
#                                         <RegexNode called "WS" matching "   ">
#                                         <Node called "AS" matching "as">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "string_expr" matching ""the value of the choice"">
#                                             <Node called "string_literal" matching ""the value of the choice"">
#                                                 <Node called "val_string" matching ""the value of the choice"">
#                                                     <Node matching """>
#                                                     <RegexNode matching "the value of the choice">
#                                                     <Node matching """>
#                                         <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                                 <Node called "annot_stmt__" matching ".correct as "you decide whether this choice is correct or not";
#                                     ">
#                                     <Node called "annot_stmt" matching ".correct as "you decide whether this choice is correct or not";">
#                                         <Node called "path_expr" matching ".correct">
#                                             <Node called "local_path_expr" matching ".correct">
#                                                 <Node called "PERIOD" matching ".">
#                                                 <Node called "sub_path_expr" matching "correct">
#                                                     <Node called "path_step" matching "correct">
#                                                         <RegexNode called "identifier" matching "correct">
#                                                         <Node matching "">
#                                                     <Node matching "">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "AS" matching "as">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "string_expr" matching ""you decide whether this choice is correct or not"">
#                                             <Node called "string_literal" matching ""you decide whether this choice is correct or not"">
#                                                 <Node called "val_string" matching ""you decide whether this choice is correct or not"">
#                                                     <Node matching """>
#                                                     <RegexNode matching "you decide whether this choice is correct or not">
#                                                     <Node matching """>
#                                         <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                         ">
#                             <Node called "RCB" matching "}">
#                     <RegexNode called "WS" matching "
#                     ">
#                     <Node called "RCB" matching "}">
#         <Node called "declaration__" matching "
#
#         prompt mmlu_main {
#             is {
#                 topic      is text;
#                 question   is text;
#                 choices[4] is a_choice;
#                 answer     is repeat(.choices.value);
#             }
#             channel {
#                 to .topic         from ?topic;
#                 to .question      from ?question;
#                 to .choices.value from ?choices;
#             }
#             return .answer;
#             annotate {
#                 .topic    as "the general category from which the question was taken";
#                 .question as "the question that you have to answer";
#                 .choices  as "you judge whether each choice is correct or not";
#                 .answer   as "you repeat the value of the choice that best answer the question";
#             }
#         }">
#             <RegexNode called "WS" matching "
#
#             ">
#             <Node called "declaration" matching "prompt mmlu_main {
#                 is {
#                     topic      is text;
#                     question   is text;
#                     choices[4] is a_choice;
#                     answer     is repeat(.choices.value);
#                 }
#                 channel {
#                     to .topic         from ?topic;
#                     to .question      from ?question;
#                     to .choices.value from ?choices;
#                 }
#                 return .answer;
#                 annotate {
#                     .topic    as "the general category from which the question was taken";
#                     .question as "the question that you have to answer";
#                     .choices  as "you judge whether each choice is correct or not";
#                     .answer   as "you repeat the value of the choice that best answer the question";
#                 }
#             }">
#                 <Node called "prompt_decl" matching "prompt mmlu_main {
#                     is {
#                         topic      is text;
#                         question   is text;
#                         choices[4] is a_choice;
#                         answer     is repeat(.choices.value);
#                     }
#                     channel {
#                         to .topic         from ?topic;
#                         to .question      from ?question;
#                         to .choices.value from ?choices;
#                     }
#                     return .answer;
#                     annotate {
#                         .topic    as "the general category from which the question was taken";
#                         .question as "the question that you have to answer";
#                         .choices  as "you judge whether each choice is correct or not";
#                         .answer   as "you repeat the value of the choice that best answer the question";
#                     }
#                 }">
#                     <Node called "PROMPT" matching "prompt">
#                     <RegexNode called "WS" matching " ">
#                     <RegexNode called "identifier" matching "mmlu_main">
#                     <RegexNode called "WS" matching " ">
#                     <Node called "LCB" matching "{">
#                     <Node called "var_decls" matching "">
#                     <RegexNode called "WS" matching "
#                         ">
#                     <Node called "is_record_field" matching "is {
#                             topic      is text;
#                             question   is text;
#                             choices[4] is a_choice;
#                             answer     is repeat(.choices.value);
#                         }">
#                         <Node called "IS" matching "is">
#                         <RegexNode called "WS" matching " ">
#                         <Node called "LCB" matching "{">
#                         <Node called "field_decls" matching "
#                                 topic      is text;
#                                 question   is text;
#                                 choices[4] is a_choice;
#                                 answer     is repeat(.choices.value);
#                             ">
#                             <Node called "field_decl__" matching "
#                                     topic      is text;
#                                     ">
#                                 <RegexNode called "WS" matching "
#                                         ">
#                                 <Node called "field_decl" matching "topic      is text;
#                                         ">
#                                     <Node called "field_name" matching "topic">
#                                         <RegexNode called "identifier" matching "topic">
#                                         <Node matching "">
#                                     <RegexNode called "WS" matching "      ">
#                                     <Node called "field_defn" matching "is text;">
#                                         <Node called "is_format_field" matching "is text;">
#                                             <Node called "IS" matching "is">
#                                             <RegexNode called "WS" matching " ">
#                                             <Node matching "text">
#                                                 <Node called "type_ref" matching "text">
#                                                     <RegexNode called "identifier" matching "text">
#                                                     <RegexNode called "WS" matching "">
#                                                     <Node matching "">
#                                             <RegexNode called "WS" matching "">
#                                             <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                             <Node called "field_decl__" matching "question   is text;
#                                     ">
#                                 <RegexNode called "WS" matching "">
#                                 <Node called "field_decl" matching "question   is text;
#                                         ">
#                                     <Node called "field_name" matching "question">
#                                         <RegexNode called "identifier" matching "question">
#                                         <Node matching "">
#                                     <RegexNode called "WS" matching "   ">
#                                     <Node called "field_defn" matching "is text;">
#                                         <Node called "is_format_field" matching "is text;">
#                                             <Node called "IS" matching "is">
#                                             <RegexNode called "WS" matching " ">
#                                             <Node matching "text">
#                                                 <Node called "type_ref" matching "text">
#                                                     <RegexNode called "identifier" matching "text">
#                                                     <RegexNode called "WS" matching "">
#                                                     <Node matching "">
#                                             <RegexNode called "WS" matching "">
#                                             <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                             <Node called "field_decl__" matching "choices[4] is a_choice;
#                                     ">
#                                 <RegexNode called "WS" matching "">
#                                 <Node called "field_decl" matching "choices[4] is a_choice;
#                                         ">
#                                     <Node called "field_name" matching "choices[4]">
#                                         <RegexNode called "identifier" matching "choices">
#                                         <Node matching "[4]">
#                                             <Node called "array_slice" matching "[4]">
#                                                 <Node called "LSB" matching "[">
#                                                 <RegexNode called "WS" matching "">
#                                                 <Node called "expression" matching "4">
#                                                     <Node called "value_expr" matching "4">
#                                                         <Node called "int_literal__" matching "4">
#                                                             <RegexNode called "int_literal" matching "4">
#                                                 <Node called "array_slice_cont" matching "">
#                                                 <RegexNode called "WS" matching "">
#                                                 <Node called "RSB" matching "]">
#                                     <RegexNode called "WS" matching " ">
#                                     <Node called "field_defn" matching "is a_choice;">
#                                         <Node called "is_format_field" matching "is a_choice;">
#                                             <Node called "IS" matching "is">
#                                             <RegexNode called "WS" matching " ">
#                                             <Node matching "a_choice">
#                                                 <Node called "type_ref" matching "a_choice">
#                                                     <RegexNode called "identifier" matching "a_choice">
#                                                     <RegexNode called "WS" matching "">
#                                                     <Node matching "">
#                                             <RegexNode called "WS" matching "">
#                                             <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                             <Node called "field_decl__" matching "answer     is repeat(.choices.value);
#                                 ">
#                                 <RegexNode called "WS" matching "">
#                                 <Node called "field_decl" matching "answer     is repeat(.choices.value);
#                                     ">
#                                     <Node called "field_name" matching "answer">
#                                         <RegexNode called "identifier" matching "answer">
#                                         <Node matching "">
#                                     <RegexNode called "WS" matching "     ">
#                                     <Node called "field_defn" matching "is repeat(.choices.value);">
#                                         <Node called "is_format_field" matching "is repeat(.choices.value);">
#                                             <Node called "IS" matching "is">
#                                             <RegexNode called "WS" matching " ">
#                                             <Node matching "repeat(.choices.value)">
#                                                 <Node called "repeat_def" matching "repeat(.choices.value)">
#                                                     <Node called "REPEAT" matching "repeat">
#                                                     <RegexNode called "WS" matching "">
#                                                     <Node called "LPAR" matching "(">
#                                                     <Node called "path_expr" matching ".choices.value">
#                                                         <Node called "local_path_expr" matching ".choices.value">
#                                                             <Node called "PERIOD" matching ".">
#                                                             <Node called "sub_path_expr" matching "choices.value">
#                                                                 <Node called "path_step" matching "choices">
#                                                                     <RegexNode called "identifier" matching "choices">
#                                                                     <Node matching "">
#                                                                 <Node matching ".value">
#                                                                     <Node called "sub_path_expr__" matching ".value">
#                                                                         <Node called "PERIOD" matching ".">
#                                                                         <Node called "sub_path_expr" matching "value">
#                                                                             <Node called "path_step" matching "value">
#                                                                                 <RegexNode called "identifier" matching "value">
#                                                                                 <Node matching "">
#                                                                             <Node matching "">
#                                                     <Node called "RPAR" matching ")">
#                                             <RegexNode called "WS" matching "">
#                                             <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                         ">
#                         <RegexNode called "WS" matching "">
#                         <Node called "RCB" matching "}">
#                     <RegexNode called "WS" matching "
#                         ">
#                     <Node called "channel_block__" matching "channel {
#                             to .topic         from ?topic;
#                             to .question      from ?question;
#                             to .choices.value from ?choices;
#                         }">
#                         <Node called "channel_block" matching "channel {
#                                 to .topic         from ?topic;
#                                 to .question      from ?question;
#                                 to .choices.value from ?choices;
#                             }">
#                             <Node called "CHANNEL" matching "channel">
#                             <RegexNode called "WS" matching " ">
#                             <Node called "LCB" matching "{">
#                             <RegexNode called "WS" matching "
#                                     ">
#                             <Node matching "to .topic         from ?topic;
#                                     to .question      from ?question;
#                                     to .choices.value from ?choices;
#                                 ">
#                                 <Node called "channel_stmt__" matching "to .topic         from ?topic;
#                                         ">
#                                     <Node called "channel_stmt" matching "to .topic         from ?topic;">
#                                         <Node called "TO" matching "to">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "local_path_expr" matching ".topic">
#                                             <Node called "PERIOD" matching ".">
#                                             <Node called "sub_path_expr" matching "topic">
#                                                 <Node called "path_step" matching "topic">
#                                                     <RegexNode called "identifier" matching "topic">
#                                                     <Node matching "">
#                                                 <Node matching "">
#                                         <RegexNode called "WS" matching "         ">
#                                         <Node matching "from ?topic;">
#                                             <Node called "from_stmt" matching "from ?topic;">
#                                                 <Node called "FROM" matching "from">
#                                                 <RegexNode called "WS" matching " ">
#                                                 <Node called "path_expr" matching "?topic">
#                                                     <Node called "input_path_expr" matching "?topic">
#                                                         <Node called "QMARK" matching "?">
#                                                         <Node called "sub_path_expr" matching "topic">
#                                                             <Node called "path_step" matching "topic">
#                                                                 <RegexNode called "identifier" matching "topic">
#                                                                 <Node matching "">
#                                                             <Node matching "">
#                                                 <RegexNode called "WS" matching "">
#                                                 <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                                 <Node called "channel_stmt__" matching "to .question      from ?question;
#                                         ">
#                                     <Node called "channel_stmt" matching "to .question      from ?question;">
#                                         <Node called "TO" matching "to">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "local_path_expr" matching ".question">
#                                             <Node called "PERIOD" matching ".">
#                                             <Node called "sub_path_expr" matching "question">
#                                                 <Node called "path_step" matching "question">
#                                                     <RegexNode called "identifier" matching "question">
#                                                     <Node matching "">
#                                                 <Node matching "">
#                                         <RegexNode called "WS" matching "      ">
#                                         <Node matching "from ?question;">
#                                             <Node called "from_stmt" matching "from ?question;">
#                                                 <Node called "FROM" matching "from">
#                                                 <RegexNode called "WS" matching " ">
#                                                 <Node called "path_expr" matching "?question">
#                                                     <Node called "input_path_expr" matching "?question">
#                                                         <Node called "QMARK" matching "?">
#                                                         <Node called "sub_path_expr" matching "question">
#                                                             <Node called "path_step" matching "question">
#                                                                 <RegexNode called "identifier" matching "question">
#                                                                 <Node matching "">
#                                                             <Node matching "">
#                                                 <RegexNode called "WS" matching "">
#                                                 <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                                 <Node called "channel_stmt__" matching "to .choices.value from ?choices;
#                                     ">
#                                     <Node called "channel_stmt" matching "to .choices.value from ?choices;">
#                                         <Node called "TO" matching "to">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "local_path_expr" matching ".choices.value">
#                                             <Node called "PERIOD" matching ".">
#                                             <Node called "sub_path_expr" matching "choices.value">
#                                                 <Node called "path_step" matching "choices">
#                                                     <RegexNode called "identifier" matching "choices">
#                                                     <Node matching "">
#                                                 <Node matching ".value">
#                                                     <Node called "sub_path_expr__" matching ".value">
#                                                         <Node called "PERIOD" matching ".">
#                                                         <Node called "sub_path_expr" matching "value">
#                                                             <Node called "path_step" matching "value">
#                                                                 <RegexNode called "identifier" matching "value">
#                                                                 <Node matching "">
#                                                             <Node matching "">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node matching "from ?choices;">
#                                             <Node called "from_stmt" matching "from ?choices;">
#                                                 <Node called "FROM" matching "from">
#                                                 <RegexNode called "WS" matching " ">
#                                                 <Node called "path_expr" matching "?choices">
#                                                     <Node called "input_path_expr" matching "?choices">
#                                                         <Node called "QMARK" matching "?">
#                                                         <Node called "sub_path_expr" matching "choices">
#                                                             <Node called "path_step" matching "choices">
#                                                                 <RegexNode called "identifier" matching "choices">
#                                                                 <Node matching "">
#                                                             <Node matching "">
#                                                 <RegexNode called "WS" matching "">
#                                                 <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                         ">
#                             <Node called "RCB" matching "}">
#                     <RegexNode called "WS" matching "
#                         ">
#                     <Node called "flow_block__" matching "">
#                     <RegexNode called "WS" matching "">
#                     <Node called "return_stmt__" matching "return .answer;">
#                         <Node called "return_stmt" matching "return .answer;">
#                             <Node called "RETURN" matching "return">
#                             <RegexNode called "WS" matching " ">
#                             <Node matching ".answer;">
#                                 <Node called "return_expr" matching ".answer;">
#                                     <Node called "path_expr" matching ".answer">
#                                         <Node called "local_path_expr" matching ".answer">
#                                             <Node called "PERIOD" matching ".">
#                                             <Node called "sub_path_expr" matching "answer">
#                                                 <Node called "path_step" matching "answer">
#                                                     <RegexNode called "identifier" matching "answer">
#                                                     <Node matching "">
#                                                 <Node matching "">
#                                     <RegexNode called "WS" matching "">
#                                     <Node called "SC" matching ";">
#                     <RegexNode called "WS" matching "
#                         ">
#                     <Node called "annot_block__" matching "annotate {
#                             .topic    as "the general category from which the question was taken";
#                             .question as "the question that you have to answer";
#                             .choices  as "you judge whether each choice is correct or not";
#                             .answer   as "you repeat the value of the choice that best answer the question";
#                         }">
#                         <Node called "annot_block" matching "annotate {
#                                 .topic    as "the general category from which the question was taken";
#                                 .question as "the question that you have to answer";
#                                 .choices  as "you judge whether each choice is correct or not";
#                                 .answer   as "you repeat the value of the choice that best answer the question";
#                             }">
#                             <Node called "ANNOTATE" matching "annotate">
#                             <RegexNode called "WS" matching " ">
#                             <Node called "LCB" matching "{">
#                             <RegexNode called "WS" matching "
#                                     ">
#                             <Node matching ".topic    as "the general category from which the question was taken";
#                                     .question as "the question that you have to answer";
#                                     .choices  as "you judge whether each choice is correct or not";
#                                     .answer   as "you repeat the value of the choice that best answer the question";
#                                 ">
#                                 <Node called "annot_stmt__" matching ".topic    as "the general category from which the question was taken";
#                                         ">
#                                     <Node called "annot_stmt" matching ".topic    as "the general category from which the question was taken";">
#                                         <Node called "path_expr" matching ".topic">
#                                             <Node called "local_path_expr" matching ".topic">
#                                                 <Node called "PERIOD" matching ".">
#                                                 <Node called "sub_path_expr" matching "topic">
#                                                     <Node called "path_step" matching "topic">
#                                                         <RegexNode called "identifier" matching "topic">
#                                                         <Node matching "">
#                                                     <Node matching "">
#                                         <RegexNode called "WS" matching "    ">
#                                         <Node called "AS" matching "as">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "string_expr" matching ""the general category from which the question was taken"">
#                                             <Node called "string_literal" matching ""the general category from which the question was taken"">
#                                                 <Node called "val_string" matching ""the general category from which the question was taken"">
#                                                     <Node matching """>
#                                                     <RegexNode matching "the general category from which the question was taken">
#                                                     <Node matching """>
#                                         <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                                 <Node called "annot_stmt__" matching ".question as "the question that you have to answer";
#                                         ">
#                                     <Node called "annot_stmt" matching ".question as "the question that you have to answer";">
#                                         <Node called "path_expr" matching ".question">
#                                             <Node called "local_path_expr" matching ".question">
#                                                 <Node called "PERIOD" matching ".">
#                                                 <Node called "sub_path_expr" matching "question">
#                                                     <Node called "path_step" matching "question">
#                                                         <RegexNode called "identifier" matching "question">
#                                                         <Node matching "">
#                                                     <Node matching "">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "AS" matching "as">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "string_expr" matching ""the question that you have to answer"">
#                                             <Node called "string_literal" matching ""the question that you have to answer"">
#                                                 <Node called "val_string" matching ""the question that you have to answer"">
#                                                     <Node matching """>
#                                                     <RegexNode matching "the question that you have to answer">
#                                                     <Node matching """>
#                                         <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                                 <Node called "annot_stmt__" matching ".choices  as "you judge whether each choice is correct or not";
#                                         ">
#                                     <Node called "annot_stmt" matching ".choices  as "you judge whether each choice is correct or not";">
#                                         <Node called "path_expr" matching ".choices">
#                                             <Node called "local_path_expr" matching ".choices">
#                                                 <Node called "PERIOD" matching ".">
#                                                 <Node called "sub_path_expr" matching "choices">
#                                                     <Node called "path_step" matching "choices">
#                                                         <RegexNode called "identifier" matching "choices">
#                                                         <Node matching "">
#                                                     <Node matching "">
#                                         <RegexNode called "WS" matching "  ">
#                                         <Node called "AS" matching "as">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "string_expr" matching ""you judge whether each choice is correct or not"">
#                                             <Node called "string_literal" matching ""you judge whether each choice is correct or not"">
#                                                 <Node called "val_string" matching ""you judge whether each choice is correct or not"">
#                                                     <Node matching """>
#                                                     <RegexNode matching "you judge whether each choice is correct or not">
#                                                     <Node matching """>
#                                         <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                             ">
#                                 <Node called "annot_stmt__" matching ".answer   as "you repeat the value of the choice that best answer the question";
#                                     ">
#                                     <Node called "annot_stmt" matching ".answer   as "you repeat the value of the choice that best answer the question";">
#                                         <Node called "path_expr" matching ".answer">
#                                             <Node called "local_path_expr" matching ".answer">
#                                                 <Node called "PERIOD" matching ".">
#                                                 <Node called "sub_path_expr" matching "answer">
#                                                     <Node called "path_step" matching "answer">
#                                                         <RegexNode called "identifier" matching "answer">
#                                                         <Node matching "">
#                                                     <Node matching "">
#                                         <RegexNode called "WS" matching "   ">
#                                         <Node called "AS" matching "as">
#                                         <RegexNode called "WS" matching " ">
#                                         <Node called "string_expr" matching ""you repeat the value of the choice that best answer the question"">
#                                             <Node called "string_literal" matching ""you repeat the value of the choice that best answer the question"">
#                                                 <Node called "val_string" matching ""you repeat the value of the choice that best answer the question"">
#                                                     <Node matching """>
#                                                     <RegexNode matching "you repeat the value of the choice that best answer the question">
#                                                     <Node matching """>
#                                         <Node called "SC" matching ";">
#                                     <RegexNode called "WS" matching "
#                                         ">
#                             <Node called "RCB" matching "}">
#                     <RegexNode called "WS" matching "
#                     ">
#                     <Node called "RCB" matching "}">
#     <RegexNode called "WS" matching "
#     ">

# %% [markdown]
# ## Flow between prompts and formats
#
# **Note**:
#  - annotation with f-exp `f"{var}"`
#  - global `flow` declares possible entry point
#    - entry point defaults to `main`
#    - if not precised the first prompt defaults to be `main`

# %%
tree = grammar.parse("""
format sentence {
    argument N=30;
    is text<N>;
    annotate f"A grammatically correct sentence made of at most {N} tokens.";
}

prompt mmlu_main {
    define K=50;
    is {
        topic       is text;
        question    is text;
        hyphothesis is sentence<K>;
    }
    channel {
        to .topic    from ?topic;
        to .question from ?question;
    }
    flow {
        to mmlu_choose;
    }
}

prompt mmlu_choose {
    is {
        topic       is text;
        question    is text;
        hyphothesis is sentence;
        choices[4]  is text;
        answer      is repeat(.choices.value);
    }
    channel {
        to .topic         from ?topic;
        to .question      from ?question;
        to .choices.value from ?choices;
        to .hyphothesis   from mmlu_main.hyphothesis;
    }
    return .answer;
}

flow {
    to mmlu_main as "main";
}
""")

# %% [markdown]
# ## Iterations
#
# **Note**:
#  - use of `as` in both `flow` and `return`, when prompt ends LLM will have to choose between `retry` and `ready`
#    - without `as` choice would have been `mmlu_main` or `return`
#  - `[5]` in the flow section limits the trip count on that branch ensuring termination

# %%
tree = grammar.parse("""
prompt mmlu_main {
    is {
        topic         is text;
        question      is text;
        choices[4]    is text;
        previous[0:1] is text<20>;
        answer        is repeat(.choices.value);
        reflect       is text<20>;
    }
    channel {
        to .topic         from ?topic;
        to .question      from ?question;
        to .choices.value from ?choices;
        to .previous      from .reflect;
    }
    flow {
        to mmlu_main[5] as "retry";
    }
    return {
        as "ready";
        from .answer;
    }
}
""")

# %% [markdown]
# ## Calls
#
# **Note**:
#  -

# %%
tree = grammar.parse("""
prompt mmlu_main {
    is {
        topic is text;
        question is text;
        choices[4] is {
            value is text;
            correct is bool;
        }
        answer is repeat(.choices.value);
    }
    channel {
        to .topic    from ?topic;
        to .question from ?question;
        to .choices call {
            entry mmlu_annot;
            kwarg topic    from ?topic;
            kwarg question from ?question;
            kwarg choice   map  ?choices;
            bind choice.subfld as value;
        }
    }
    return {
        from .answer;
    }
}

prompt mmlu_annot {
    is {
        topic    is text;
        question is text;
        choice   is text;
        correct  is bool;
    }
    channel {
        to .topic    from ?topic;
        to .question from ?question;
        to .choice   from ?choice;
    }
    return {
        from .choice;
        from .correct;
    }
}
""")
